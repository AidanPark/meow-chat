# %% [markdown]
# ### 🏥 고양이 의료 문서 분석
#
# 고양이 의료 문서 분석 단계
#
# - 전처리 > Tesseract

# %% [markdown]
# ### 1. 환경 설정 및 라이브러리 로드

# %%
# 1. Tesseract 한국어 언어팩 설치 확인
# sudo apt-get update
# sudo apt-get install -y tesseract-ocr-kor

# 2. 설치된 언어 확인
# !tesseract --list-langs

# 3. 한국어 언어팩 다운로드 (위 명령어로 설치가 안 된 경우)
# !wget https://github.com/tesseract-ocr/tessdata/raw/main/kor.traineddata -O /usr/share/tesseract-ocr/4.00/tessdata/kor.traineddata

# %%
# 필요한 라이브러리 설치
# !pip install pytesseract pymupdf opencv-python

# %% [markdown]
# ### 2. 업로드 파일 전처리

# %%
import io
from re import T
from typing import List, Dict, Any, Tuple, Callable, Sequence, Optional
import fitz
import tempfile
from PIL import Image, ImageFilter, ImageOps

import numpy as np
from pytesseract import image_to_data, Output
import cv2 

# ---------- 공통 보조 ----------
def _pil_to_cv(img: Image.Image) -> np.ndarray:
    arr = np.array(img)
    if arr.ndim == 2:
        return arr
    if arr.shape[2] == 4:
        # RGBA -> RGB
        arr = cv2.cvtColor(arr, cv2.COLOR_RGBA2RGB) if cv2 is not None else arr[:, :, :3]
    # RGB -> BGR
    return cv2.cvtColor(arr, cv2.COLOR_RGB2BGR) if cv2 is not None else arr[:, :, ::-1]

def _cv_to_pil(arr: np.ndarray) -> Image.Image:
    if arr.ndim == 2:
        return Image.fromarray(arr)
    # BGR -> RGB
    if cv2 is not None:
        arr = cv2.cvtColor(arr, cv2.COLOR_BGR2RGB)
    else:
        arr = arr[:, :, ::-1]
    return Image.fromarray(arr)

def _order_quad(pts: np.ndarray) -> np.ndarray:
    # pts: (4,2)
    s = pts.sum(axis=1)
    diff = np.diff(pts, axis=1).ravel()
    tl = pts[np.argmin(s)]
    br = pts[np.argmax(s)]
    tr = pts[np.argmin(diff)]
    bl = pts[np.argmax(diff)]
    return np.array([tl, tr, br, bl], dtype=np.float32)

def pdf_to_images(pdf_path: str, resolution_scale: float = 1.5) -> List[bytes]:
    """
    PDF 파일 경로를 받아 각 페이지를 PNG 바이트로 변환해 리스트로 반환
    """
    png_list: List[bytes] = []
    doc = None
    try:
        doc = fitz.open(pdf_path)
        mat = fitz.Matrix(resolution_scale, resolution_scale)
        for page in doc:
            pix = page.get_pixmap(matrix=mat, alpha=False)
            png_list.append(pix.tobytes("png"))
    finally:
        try:
            if doc is not None:
                doc.close()
        except Exception:
            pass
    return png_list

# ---------- 로드+EXIF 회전 교정 ----------
def open_with_exif(img_bytes: bytes):
    """
    1) 로드 + EXIF 회전 교정: 카메라 회전 정보가 있으면 실제 픽셀을 회전
    """
    img = Image.open(io.BytesIO(img_bytes))
    try:
        img = ImageOps.exif_transpose(img)
    except Exception:
        pass
    return img

# ---------- 투명 채널 플래튼 ----------
def flatten_transparency(img: Image.Image) -> Image.Image:
    """
    2) 투명 채널 플래튼: RGBA/LA → 흰 배경 위에 합성 (기호/점 주변 헤일로 방지)
    """
    if img.mode in ("RGBA", "LA"):
        bg = Image.new("RGB", img.size, (255, 255, 255))
        alpha = img.split()[-1]
        return Image.composite(img.convert("RGB"), bg, alpha)
    return img

# ---------- 여백 기반 자동 크롭 ----------
def auto_crop_with_margin(img: Image.Image, margin: int = 10) -> Image.Image:
    """
    3) 자동 크롭: 흰 배경을 기준으로 내용물 bbox를 찾고 margin만큼 여유
    """
    gray = img.convert("L")
    inv = ImageOps.invert(gray)  # 흰색 배경 → 0, 잉크 → 양수
    bbox = inv.getbbox()
    if not bbox:
        return img
    x0, y0, x1, y1 = bbox
    x0 = max(0, x0 - margin)
    y0 = max(0, y0 - margin)
    x1 = min(img.width,  x1 + margin)
    y1 = min(img.height, y1 + margin)
    return img.crop((x0, y0, x1, y1))

# ---------- 문서 외곽 사변형 경계 탐지 ----------
def detect_document_quad(img: Image.Image, min_area_ratio: float = 0.2, debug: bool = False) -> Optional[List[Tuple[int, int]]]:
    """
    new detect_document_quad(문서 외곽 사변형 경계 탐지)
    - 성공 시 좌상, 우상, 우하, 좌하 4점 반환, 실패 시 None
    """
    if cv2 is None:
        if debug: print("[detect_document_quad] OpenCV 미설치 - 건너뜀")
        return None
    im = _pil_to_cv(img)
    h, w = im.shape[:2]
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY) if im.ndim == 3 else im
    gray = cv2.GaussianBlur(gray, (5,5), 0)
    edges = cv2.Canny(gray, 50, 150)
    edges = cv2.dilate(edges, np.ones((5,5), np.uint8), iterations=1)
    cnts, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = sorted(cnts, key=cv2.contourArea, reverse=True)
    img_area = w*h
    for c in cnts[:8]:
        area = cv2.contourArea(c)
        if area < img_area * min_area_ratio:
            continue
        peri = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, 0.02 * peri, True)
        if len(approx) == 4:
            quad = approx.reshape(-1, 2).astype(np.float32)
            quad = _order_quad(quad)
            if debug: print(f"[detect_document_quad] 사변형 발견 - area ratio={area/img_area:.2f}")
            return [(int(x), int(y)) for x, y in quad]
    if debug: print("[detect_document_quad] 사변형 미발견")
    return None

# ---------- 사변형 → 직사각 투시 보정 ----------
def perspective_unwarp(img: Image.Image, quad: Optional[List[Tuple[int,int]]] = None, keep_aspect: bool = True, padding: int = 0, debug: bool = False) -> Image.Image:
    """
    new perspective_unwarp(사변형 → 직사각 투시 보정)
    - quad가 없으면 자동 검출을 시도
    """
    if cv2 is None:
        if debug: print("[perspective_unwarp] OpenCV 미설치 - 원본 반환")
        return img
    if quad is None:
        quad = detect_document_quad(img, debug=debug)
    if quad is None:
        if debug: print("[perspective_unwarp] 경계 미검출 - 원본 반환")
        return img

    im = _pil_to_cv(img)
    h, w = im.shape[:2]
    src = np.array(quad, dtype=np.float32)

    # 목표 크기 추정
    tl, tr, br, bl = src
    widthA = np.linalg.norm(br - bl)
    widthB = np.linalg.norm(tr - tl)
    heightA = np.linalg.norm(tr - br)
    heightB = np.linalg.norm(tl - bl)
    dst_w = int(max(widthA, widthB))
    dst_h = int(max(heightA, heightB))
    if keep_aspect and dst_w > 0 and dst_h > 0:
        aspect = dst_w / (dst_h + 1e-6)
        # 의료 양식(세로형)이 흔해 약간의 정규화
        if aspect < 0.6:  # 너무 세로 길면 살짝 보정
            dst_w = int(dst_h * 0.7)

    dst = np.array([[0,0],[dst_w-1,0],[dst_w-1,dst_h-1],[0,dst_h-1]], dtype=np.float32)
    M = cv2.getPerspectiveTransform(src, dst)
    warped = cv2.warpPerspective(im, M, (dst_w, dst_h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)

    if padding > 0:
        warped = cv2.copyMakeBorder(warped, padding, padding, padding, padding, cv2.BORDER_CONSTANT, value=(255,255,255))
    if debug: print(f"[perspective_unwarp] 완료 → {dst_w}x{dst_h}")
    return _cv_to_pil(warped)

# ---------- OSD + 텍스트 라인 기반 미세 기울기 보정 ----------
def deskew_textlines(
    img: Image.Image,
    max_angle: float = 12.0,
    refine: bool = True,
    refine_range: float = 1.2,   # ± 탐색 범위(도)
    refine_step: float = 0.05,   # 탐색 간격(도)
    pad: int = 12,               # 회전 전 여백(클리핑 방지)
    debug: bool = False,
) -> Image.Image:
    """
    수평 선 강조 + Hough로 '대략 각도' 추정 후,
    작은 범위에서 행 프로젝션 점수로 정밀 탐색해 교정.
    """
    if cv2 is None:
        if debug: print("[deskew_textlines] OpenCV 미설치 - 원본 반환")
        return img

    im0 = _pil_to_cv(img)
    if pad > 0:
        im = cv2.copyMakeBorder(im0, pad, pad, pad, pad, cv2.BORDER_REPLICATE)
    else:
        im = im0

    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY) if im.ndim == 3 else im
    gray = cv2.GaussianBlur(gray, (5, 5), 0)
    thr = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
    bw_inv = 255 - thr
    h, w = gray.shape[:2]

    # 수평 구조 강조(커널 폭 소폭 증가 → 안정적 각도 추정)
    kx = max(21, w // 30)
    hker = cv2.getStructuringElement(cv2.MORPH_RECT, (kx, 1))
    horiz = cv2.morphologyEx(bw_inv, cv2.MORPH_OPEN, hker)

    # 에지 결합
    edges = cv2.max(cv2.Canny(bw_inv, 50, 150), cv2.Canny(horiz, 50, 150))

    # 1) HoughLinesP로 대략 각도(선 길이 가중)
    min_len = max(60, int(w * 0.35))
    linesP = cv2.HoughLinesP(
        edges, 1, np.pi / 180,
        threshold=max(50, int(0.0025 * w)),
        minLineLength=min_len,
        maxLineGap=30
    )
    angles, weights = [], []
    if linesP is not None:
        for x1, y1, x2, y2 in linesP[:, 0]:
            ang = np.degrees(np.arctan2(y2 - y1, x2 - x1))
            if -max_angle <= ang <= max_angle:
                L = float(np.hypot(x2 - x1, y2 - y1))
                angles.append(ang); weights.append(L)

    # 보조: 표준 Hough
    if len(angles) < 5:
        lines = cv2.HoughLines(edges, 1, np.pi / 180, threshold=max(120, int(0.006 * w)))
        if lines is not None:
            for rho, theta in lines[:, 0]:
                ang = (theta * 180 / np.pi) - 90
                if -max_angle <= ang <= max_angle:
                    angles.append(ang); weights.append(1.0)

    coarse = float(np.average(angles, weights=weights)) if angles else 0.0
    final_angle = coarse

    # 2) 정밀 탐색(±refine_range, step=refine_step) - 행 프로젝션 점수 최대화
    if refine:
        # 속도 위해 다운스케일
        scale = 1000.0 / max(h, w)
        small = cv2.resize(bw_inv, (int(w * scale), int(h * scale)), interpolation=cv2.INTER_AREA) if scale < 1.0 else bw_inv
        sh, sw = small.shape[:2]

        def score(a_deg: float) -> float:
            M = cv2.getRotationMatrix2D((sw / 2, sh / 2), a_deg, 1.0)
            r = cv2.warpAffine(small, M, (sw, sh), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REPLICATE)
            proj = r.mean(axis=1)           # 행 방향 평균(수평선이 곧을수록 변동↑)
            d = np.diff(proj)
            return float(proj.var() + 0.5 * (d * d).mean())

        best_s, best_a = -1e9, coarse
        for a in np.arange(coarse - refine_range, coarse + refine_range + 1e-9, refine_step):
            s = score(a)
            if s > best_s:
                best_s, best_a = s, a
        final_angle = best_a

    if debug:
        print(f"[deskew_textlines] coarse={coarse:.2f}°, final={final_angle:.2f}°")

    if abs(final_angle) < 0.05:
        return img

    M = cv2.getRotationMatrix2D((w / 2, h / 2), final_angle, 1.0)
    rotated = cv2.warpAffine(im, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    if pad > 0 and rotated.shape[0] > 2 * pad and rotated.shape[1] > 2 * pad:
        rotated = rotated[pad:-pad, pad:-pad]
    return _cv_to_pil(rotated)

# ---------- 페이지 말림/곡면 보정·필요 시만 ----------
def conditional_dewarp(img: Image.Image, strength: float = 0.6, min_lines: int = 10, debug: bool = False) -> Image.Image:
    """
    new conditional_dewarp(페이지 말림/곡면 보정·필요 시만)
    - HoughLinesP로 수평 라인을 샘플링하고, x에 따른 베이스라인 곡선을 2차 다항으로 근사.
    - 각 x 컬럼마다 세로 시프트 맵을 만들어 보정(간이 방식).
    """
    if cv2 is None:
        if debug: print("[conditional_dewarp] OpenCV 미설치 - 원본 반환")
        return img
    im = _pil_to_cv(img)
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY) if im.ndim == 3 else im
    bw = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY_INV, 35, 15)
    lines = cv2.HoughLinesP(bw, 1, np.pi/180, threshold=100, minLineLength=max(40, gray.shape[1]//10), maxLineGap=10)
    if lines is None or len(lines) < min_lines:
        if debug: print("[conditional_dewarp] 라인 부족 - 스킵")
        return img

    pts_x, pts_y = [], []
    for l in lines[:,0]:
        x1,y1,x2,y2 = l
        # 거의 수평 라인만 사용
        if abs(y2 - y1) <= 3:
            xm = 0.5*(x1+x2)
            ym = 0.5*(y1+y2)
            pts_x.append(xm)
            pts_y.append(ym)
    if len(pts_x) < min_lines:
        if debug: print("[conditional_dewarp] 유효 수평 라인 부족 - 스킵")
        return img

    z = np.polyfit(np.array(pts_x), np.array(pts_y), deg=2)
    p = np.poly1d(z)
    h, w = gray.shape[:2]
    xs = np.arange(w, dtype=np.float32)
    curve = p(xs).astype(np.float32)
    shift = (curve - np.mean(curve)) * strength  # 각 컬럼의 세로 시프트

    map_x = np.tile(xs, (h,1)).astype(np.float32)
    ys = np.arange(h, dtype=np.float32)
    map_y = (np.tile(ys[:,None], (1,w)) - shift[None, :]).astype(np.float32)
    map_y = np.clip(map_y, 0, h-1)
    dewarped = cv2.remap(im, map_x, map_y, interpolation=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    if debug: print("[conditional_dewarp] 간이 디워프 적용")
    return _cv_to_pil(dewarped)

# ---------- 최소 해상도 확보 업스케일 ----------
def upscale_min_resolution(img: Image.Image, min_long_edge: int = 1200) -> Image.Image:
    """
    4) 해상도 표준화(업스케일만): 소수점/기호 선명도를 위해 최소 해상도 확보, 과대 크기는 축소하지 않음
    """
    w, h = img.size
    long_edge = max(w, h)
    if long_edge < min_long_edge:
        scale = min_long_edge / float(long_edge)
        img = img.resize((int(round(w * scale)), int(round(h * scale))), Image.LANCZOS)
    return img

# ---------- 배경 평탄화·그라디언트/그림자 제거 ----------
def illumination_flatten(img: Image.Image, blur_ratio: float = 0.03, debug: bool = False) -> Image.Image:
    """
    new illumination_flatten(배경 평탄화·그림자 제거)
    - 큰 가우시안 블러로 배경을 추정 후 L(밝기) 채널에서 평탄화
    """
    if cv2 is None:
        if debug: print("[illumination_flatten] OpenCV 미설치 - 원본 반환")
        return img
    im = _pil_to_cv(img)
    if im.ndim == 3:
        lab = cv2.cvtColor(im, cv2.COLOR_BGR2LAB)
        L, A, B = cv2.split(lab)
        k = max(3, int(round(max(im.shape[:2]) * blur_ratio)) | 1)
        bg = cv2.GaussianBlur(L, (k, k), 0)
        flat = cv2.normalize(cv2.subtract(L, bg) + 128, None, 0, 255, cv2.NORM_MINMAX)
        lab = cv2.merge([flat, A, B])
        out = cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)
    else:
        k = max(3, int(round(max(im.shape[:2]) * blur_ratio)) | 1)
        bg = cv2.GaussianBlur(im, (k, k), 0)
        out = cv2.normalize(cv2.subtract(im, bg) + 128, None, 0, 255, cv2.NORM_MINMAX)
    if debug: print(f"[illumination_flatten] k={k} 적용")
    return _cv_to_pil(out)

# ---------- 하이라이트/빛반사 감쇠 ----------
def suppress_glare(img: Image.Image, v_high: int = 230, s_low: int = 40, debug: bool = False) -> Image.Image:
    """
    new suppress_glare(하이라이트/빛반사 감쇠)
    - HSV에서 S 낮고 V 높은 영역을 완만히 억제
    """
    if cv2 is None:
        if debug: print("[suppress_glare] OpenCV 미설치 - 원본 반환")
        return img
    im = _pil_to_cv(img)
    hsv = cv2.cvtColor(im, cv2.COLOR_BGR2HSV) if im.ndim == 3 else cv2.cvtColor(cv2.cvtColor(im, cv2.COLOR_GRAY2BGR), cv2.COLOR_BGR2HSV)
    H, S, V = cv2.split(hsv)
    mask = cv2.inRange(S, 0, s_low) & cv2.inRange(V, v_high, 255)
    # 밝기 완만 감소
    V2 = V.copy()
    V2[mask > 0] = (0.85 * V2[mask > 0]).astype(np.uint8)
    hsv2 = cv2.merge([H, S, V2])
    out = cv2.cvtColor(hsv2, cv2.COLOR_HSV2BGR)
    if debug: print("[suppress_glare] 글레어 감쇠 적용")
    return _cv_to_pil(out)

# ---------- 이미지 모드 정규화 ----------
def normalize_mode(img: Image.Image) -> Image.Image:
    """
    5) 모드 정규화: 이후 연산 호환을 위해 L 또는 RGB로 제한
    """
    if img.mode not in ("L", "RGB"):
        return img.convert("RGB")
    return img

# ---------- 약한 전역 대비 보정 ----------
def weak_autocontrast(img: Image.Image, cutoff: float = 0.4) -> Image.Image:
    """
    6) 자동 대비: 낮은 컷오프(0.4%)로 미세 픽셀(소수점·단위) 클리핑 방지
    """
    return ImageOps.autocontrast(img, cutoff=cutoff)

# ---------- 로컬 대비 향상·과도 시 비활성화 ----------
def apply_clahe(img: Image.Image, clip_limit: float = 2.0, tile_grid: Tuple[int,int] = (8,8), enabled: bool = True, debug: bool = False) -> Image.Image:
    """
    new apply_clahe(로컬 대비 향상·과도 시 비활성화)
    """
    if not enabled:
        return img
    if cv2 is None:
        if debug: print("[apply_clahe] OpenCV 미설치 - 원본 반환")
        return img
    im = _pil_to_cv(img)
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid)
    if im.ndim == 3:
        lab = cv2.cvtColor(im, cv2.COLOR_BGR2LAB)
        L, A, B = cv2.split(lab)
        L2 = clahe.apply(L)
        lab2 = cv2.merge([L2, A, B])
        out = cv2.cvtColor(lab2, cv2.COLOR_LAB2BGR)
    else:
        out = clahe.apply(im)
    if debug: print("[apply_clahe] 적용 완료")
    return _cv_to_pil(out)

# ---------- 보수적 샤프닝 ----------
def conservative_sharpen(img: Image.Image, radius: float = 1.0, percent: int = 120, threshold: int = 3, enabled: bool = True) -> Image.Image:
    """
    7) 보수적 샤픈: 소수점 주변 헤일로 없이 스트로크만 강화
    """
    if not enabled:
        return img
    return img.filter(ImageFilter.UnsharpMask(radius=radius, percent=percent, threshold=threshold))

# ---------- 그레이스케일 변환 ----------
def to_grayscale(img: Image.Image, enabled: bool = True) -> Image.Image:
    """
    8) 그레이스케일: 문서형 이미지에서 텍스트 대비를 높여 인식 안정화
    """
    if enabled and img.mode != "L":
        return img.convert("L")
    return img

# ---------- 적응형 이진화·문서용 ----------
def adaptive_binarize_for_ocr(img: Image.Image, block_size: int = 25, k: float = 0.15, debug: bool = False) -> Image.Image:
    """
    new adaptive_binarize_for_ocr(적응형 이진화·문서용)
    - scikit-image의 Sauvola가 있으면 사용, 없으면 OpenCV 가우시안 적응 이진화
    """
    arr = _pil_to_cv(img)
    gray = cv2.cvtColor(arr, cv2.COLOR_BGR2GRAY) if (cv2 is not None and arr.ndim == 3) else (arr if arr.ndim == 2 else arr[:, :, 0])
    try:
        from skimage.filters import threshold_sauvola  # type: ignore
        win = block_size if block_size % 2 == 1 else block_size + 1
        thresh = threshold_sauvola(gray, window_size=win, k=k)
        bw = (gray > thresh).astype(np.uint8) * 255
        if debug: print("[adaptive_binarize_for_ocr] Sauvola 적용")
    except Exception:
        if cv2 is None:
            if debug: print("[adaptive_binarize_for_ocr] OpenCV/Skimage 없음 - 원본 반환")
            return img
        win = block_size if block_size % 2 == 1 else block_size + 1
        bw = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                   cv2.THRESH_BINARY, win, 10)
        if debug: print("[adaptive_binarize_for_ocr] OpenCV 적응 이진화 적용")
    return Image.fromarray(bw)

# ---------- 모폴로지로 표 수평/수직 라인 약 강화 ----------
def enhance_table_lines(img: Image.Image, strength: float = 0.5, debug: bool = False) -> Image.Image:
    """
    new enhance_table_lines(모폴로지로 표 수평/수직 라인 약 강화)
    - 블랙햇(black-hat)으로 어두운 선을 강조 후 원본에서 소량 감산
    """
    if cv2 is None:
        if debug: print("[enhance_table_lines] OpenCV 미설치 - 원본 반환")
        return img
    im = _pil_to_cv(img)
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY) if im.ndim == 3 else im
    h, w = gray.shape[:2]
    hk = max(3, (w // 80) | 1)
    vk = max(3, (h // 80) | 1)
    hker = cv2.getStructuringElement(cv2.MORPH_RECT, (hk, 1))
    vker = cv2.getStructuringElement(cv2.MORPH_RECT, (1, vk))
    hhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, hker)
    vhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, vker)
    comb = cv2.max(hhat, vhat)
    delta = (comb * np.clip(strength, 0.0, 1.0)).astype(np.uint8)
    enhanced = cv2.subtract(gray, delta)
    if im.ndim == 3:
        out = cv2.cvtColor(enhanced, cv2.COLOR_GRAY2BGR)
    else:
        out = enhanced
    if debug: print("[enhance_table_lines] 라인 강화 완료")
    return _cv_to_pil(out)

# ---------- TSV 앵커 기반 테이블 스마트 크롭 ----------
def table_smart_crop(
    img: Image.Image,
    enabled: bool = False,
    lang: str = "eng+kor",
    conf_min: int = 30,
    top_margin: int = 18,
    bottom_margin: int = 10,
    min_header_hits: int = 2,
    first_col_tolerance: int = 80,
    gap_multiplier: float = 2.8,
    min_rows: int = 5,
    debug: bool = True,
    min_table_height: int = 100,  # 🆕 최소 테이블 높이 파라미터
) -> Image.Image:
    """
    테이블 스마트 크롭(1순위: Tesseract TSV 앵커)
    - 상단: 헤더(국/영 키워드) 또는 바이오마커 열의 첫 클러스터 시작
    - 하단: 다음 헤더 직전 또는 큰 수직 공백(행간 중앙값*k) 직전
    - 여러 테이블이 있어도 가장 위 테이블 1개만 남김
    """
    if not enabled:
        if debug:
            print("[table_smart_crop] ⏭️ 비활성화 상태 - 원본 반환")
        return img
    
    if debug:
        print(f"[table_smart_crop] 🚀 시작 - 이미지 크기: {img.size}")
    
    try:
        pil = img if img.mode in ("L", "RGB") else img.convert("RGB")
        if debug:
            print(f"[table_smart_crop] 🖼️ 이미지 모드: {pil.mode}")

        # OCR
        if debug:
            print("[table_smart_crop] 📝 OCR 시작 (Tesseract)...")
        config = "--oem 3 --psm 4"
        data = image_to_data(pil, lang=lang, config=config, output_type=Output.DICT)
        n = len(data.get("text", []))
        if debug:
            print(f"[table_smart_crop] 📊 OCR 완료 - 총 {n}개 텍스트 요소 감지")
        
        if n == 0:
            if debug:
                print("[table_smart_crop] ⚠️ OCR 결과 없음 - 원본 반환")
            return img

        # 단어 토큰 필터링
        if debug:
            print(f"[table_smart_crop] 🔍 토큰 필터링 (최소 신뢰도: {conf_min})...")
        tokens = []
        for i in range(n):
            txt = (data["text"][i] or "").strip()
            if not txt:
                continue
            try:
                conf = float(data["conf"][i])
            except Exception:
                conf = -1
            if conf < conf_min:
                continue
            tokens.append(
                {
                    "text": txt,
                    "x": int(data["left"][i]),
                    "y": int(data["top"][i]),
                    "w": int(data["width"][i]),
                    "h": int(data["height"][i]),
                    "page": int(data["page_num"][i]),
                    "block": int(data["block_num"][i]),
                    "par": int(data["par_num"][i]),
                    "line": int(data["line_num"][i]),
                }
            )
        
        if debug:
            print(f"[table_smart_crop] ✅ 유효한 토큰: {len(tokens)}개")
        
        if not tokens:
            if debug:
                print("[table_smart_crop] ⚠️ 유효한 토큰 없음 - 원본 반환")
            return img

        # 라인 그룹핑
        if debug:
            print("[table_smart_crop] 📋 라인 그룹핑 시작...")
        from collections import defaultdict
        groups = defaultdict(list)
        for t in tokens:
            key = (t["page"], t["block"], t["par"], t["line"])
            groups[key].append(t)

        lines = []
        for key, group in groups.items():
            x0 = min(g["x"] for g in group)
            y0 = min(g["y"] for g in group)
            x1 = max(g["x"] + g["w"] for g in group)
            y1 = max(g["y"] + g["h"] for g in group)
            text_norm = " ".join(g["text"] for g in group).lower()
            lines.append({"x0": x0, "y0": y0, "x1": x1, "y1": y1, "text": text_norm})
        
        if debug:
            print(f"[table_smart_crop] ✅ 라인 그룹핑 완료: {len(lines)}개 라인")
        
        if not lines:
            if debug:
                print("[table_smart_crop] ⚠️ 라인 없음 - 원본 반환")
            return img
        
        lines.sort(key=lambda l: l["y0"])

        # 헤더 후보 판단(국/영 혼합)
        if debug:
            print("[table_smart_crop] 🔎 헤더 라인 검색 중...")
        header_kws = {
            "name", "unit", "result", "reference", "ref", "min", "max",
            "항목", "검사항목", "결과", "단위", "기준치", "참조치", "참고치"
        }
        def is_header(l) -> bool:
            hits = sum(1 for kw in header_kws if kw in l["text"])
            return hits >= min_header_hits and len(l["text"]) >= 4

        header_lines = [l for l in lines if is_header(l)]
        header_lines.sort(key=lambda l: l["y0"])
        
        if debug:
            print(f"[table_smart_crop] 📌 헤더 라인 발견: {len(header_lines)}개")
            if header_lines:
                for idx, h in enumerate(header_lines[:5]):  # 🆕 최대 5개만 출력
                    print(f"[table_smart_crop]    헤더 {idx+1}: y={h['y0']}, text='{h['text'][:50]}...'")

        # 바이오마커 앵커(헤더 실패 대비)
        if debug:
            print("[table_smart_crop] 🧬 바이오마커 검색 중...")
        biomarker_kws = {
            "rbc","hct","hgb","mcv","mch","mchc","plt","wbc",
            "retic","glucose","glu","bun","crea","creatinine","ast","alt","alp",
            "mpv","pct","rdw","neut","lymph","mono","eos","baso"
        }
        def has_biomarker(l) -> bool:
            t = l["text"].replace("−", "-")
            return any(kw in t for kw in biomarker_kws)

        # 상단 y 결정
        if header_lines:
            if debug:
                print("[table_smart_crop] ✅ 헤더 기반으로 상단 계산")
            top_header = header_lines[0]
            y_top = max(0, top_header["y0"] - top_margin)
            anchor_x = top_header["x0"]
            if debug:
                print(f"[table_smart_crop]    y_top={y_top}, anchor_x={anchor_x}")
        else:
            if debug:
                print("[table_smart_crop] 🔄 헤더 없음 - 바이오마커 앵커 사용")
            biomarker_lines = [l for l in lines if has_biomarker(l)]
            if not biomarker_lines:
                if debug:
                    print("[table_smart_crop] ❌ 바이오마커도 없음 - 원본 반환")
                return img
            
            if debug:
                print(f"[table_smart_crop] ✅ 바이오마커 라인: {len(biomarker_lines)}개")
            
            biomarker_lines.sort(key=lambda l: l["y0"])
            xs = np.array([l["x0"] for l in biomarker_lines])
            anchor_x = int(np.percentile(xs, 20))
            first_band = [l for l in biomarker_lines if abs(l["x0"] - anchor_x) <= first_col_tolerance] or biomarker_lines[:1]
            y_top = max(0, min(l["y0"] for l in first_band) - top_margin)
            if debug:
                print(f"[table_smart_crop]    y_top={y_top}, anchor_x={anchor_x}")

        # 🆕 하단 y 결정 (개선된 로직)
        if debug:
            print("[table_smart_crop] 📐 하단 경계 계산 중...")
        
        # 다음 헤더 필터링: 충분히 멀리 떨어진 헤더만 고려
        below_headers = [l for l in header_lines if l["y0"] > y_top + min_table_height]
        
        if debug:
            print(f"[table_smart_crop]    충분히 멀리 떨어진 헤더: {len(below_headers)}개 (최소 거리: {min_table_height}px)")
        
        if below_headers:
            # 다음 테이블의 헤더를 찾았다면 그 직전까지
            y_bottom = max(y_top + min_table_height, below_headers[0]["y0"] - 10)
            if debug:
                print(f"[table_smart_crop] ✅ 다음 테이블 헤더로 하단 결정: y_bottom={y_bottom}")
        else:
            # 다음 헤더가 없으면 공백 분석으로 하단 결정
            if debug:
                print("[table_smart_crop] 🔄 다음 헤더 없음 - 공백 분석으로 하단 결정")
            candidate = [l for l in lines if l["y0"] >= y_top]
            band = [l for l in candidate if abs(l["x0"] - anchor_x) <= first_col_tolerance]
            band.sort(key=lambda l: l["y0"])
            
            if debug:
                print(f"[table_smart_crop]    테이블 후보 라인: {len(band)}개")
            
            if len(band) < min_rows:
                if debug:
                    print(f"[table_smart_crop] ⚠️ 최소 행 수 부족 ({len(band)} < {min_rows})")
                    print(f"[table_smart_crop] 🔄 전체 라인에서 공백 분석 시도...")
                # 🆕 첫 열 제약 완화: 전체 라인에서 y_top 이후 모든 라인 고려
                band = [l for l in lines if l["y0"] >= y_top]
                band.sort(key=lambda l: l["y0"])
                
                if len(band) < min_rows:
                    if debug:
                        print(f"[table_smart_crop] ❌ 전체 라인도 부족 ({len(band)} < {min_rows}) - 원본 반환")
                    return img
            
            gaps = [band[i+1]["y0"] - band[i]["y1"] for i in range(len(band)-1)]
            med_gap = np.median([g for g in gaps if g >= 0]) if gaps else 20
            thresh = max(24, med_gap * gap_multiplier)
            
            if debug:
                print(f"[table_smart_crop]    행간 중앙값: {med_gap:.1f}px, 공백 임계값: {thresh:.1f}px")

            y_bottom = band[0]["y1"]
            prev_y1 = band[0]["y1"]
            row_count = 1
            for l in band[1:]:
                if (l["y0"] - prev_y1) > thresh:
                    if debug:
                        print(f"[table_smart_crop]    큰 공백 감지: {l['y0'] - prev_y1:.1f}px > {thresh:.1f}px")
                    break
                y_bottom = max(y_bottom, l["y1"])
                prev_y1 = l["y1"]
                row_count += 1
            
            y_bottom = min(img.height, int(y_bottom + bottom_margin))
            if debug:
                print(f"[table_smart_crop] ✅ 하단 결정: y_bottom={y_bottom}, 테이블 행 수={row_count}")

        # 최종 검증
        final_height = y_bottom - y_top
        if final_height < 64:
            if debug:
                print(f"[table_smart_crop] ❌ 테이블 높이 부족 ({final_height}px < 64px) - 원본 반환")
            return img

        # 크롭 실행
        cropped = img.crop((0, int(y_top), img.width, int(y_bottom)))
        if debug:
            print(f"[table_smart_crop] ✂️ 크롭 완료")
            print(f"[table_smart_crop]    원본: {img.size} → 크롭: {cropped.size}")
            print(f"[table_smart_crop]    영역: y_top={int(y_top)}, y_bottom={int(y_bottom)}")
            print(f"[table_smart_crop]    크롭 높이: {final_height}px")
        
        return cropped

    except Exception as e:
        if debug:
            print(f"[table_smart_crop] ❌ 오류 발생: {e}")
            import traceback
            traceback.print_exc()
        return img

# ---------- 얇은 흰색 테두리 추가 ----------
def add_white_border(img: Image.Image, border: int = 4) -> Image.Image:
    """
    10) 테두리 추가: 가장자리 문자가 잘리지 않도록 얇은 흰색 여백
    """
    if border and border > 0:
        fill = 255 if img.mode == "L" else (255, 255, 255)
        return ImageOps.expand(img, border=border, fill=fill)
    return img

# ---------- 목표 해상도로 다운스케일 ----------
def downscale_target_long_edge(img: Image.Image, target_long_edge: int = 1800) -> Image.Image:
    """
    11) 해상도 표준화(다운스케일 허용): 과대 크기는 축소
    """
    w, h = img.size
    long_edge = max(w, h)
    if long_edge > target_long_edge:
        scale = target_long_edge / float(long_edge)
        img = img.resize((int(round(w * scale)), int(round(h * scale))), Image.LANCZOS)
    return img

# ---------- OCR 품질 게이트 ----------
def _tesseract_metrics(pil_img: Image.Image, lang: str = "eng+kor") -> dict:
    try:
        data = image_to_data(pil_img, lang=lang, config="--oem 3 --psm 6", output_type=Output.DICT)
        confs = []
        for c in data.get("conf", []):
            try:
                v = float(c)
                if v >= 0:
                    confs.append(v)
            except Exception:
                pass
        mean_conf = float(np.mean(confs)) if confs else 0.0
        n_tokens = int(len(confs))
        return {"mean_conf": mean_conf, "tokens": n_tokens}
    except Exception:
        return {"mean_conf": 0.0, "tokens": 0}

def ocr_quality_gate(
    img: Image.Image,
    baseline_img: Optional[Image.Image] = None,
    lang: str = "eng+kor",
    min_delta_conf: float = -1.0,
    min_delta_tokens: int = -9999,
    debug: bool = True,
) -> Image.Image:
    """
    new ocr_quality_gate(토큰 수/평균 conf 기반 품질 점검·악화 시 이전 단계 롤백)
    - baseline_img가 주어지면 현재 이미지가 품질이 더 나쁘면 baseline으로 롤백
    - min_delta_*는 '현재 - 기준'의 최소 허용 변화량(음수 허용). 더 낮으면 롤백.
    """
    cur = _tesseract_metrics(img, lang=lang)
    if baseline_img is None:
        # 메트릭만 기록하고 통과
        try:
            img.info["ocr_quality"] = cur
        except Exception:
            pass
        if debug: print(f"[ocr_quality_gate] conf={cur['mean_conf']:.1f}, tokens={cur['tokens']}")
        return img

    base = _tesseract_metrics(baseline_img, lang=lang)
    d_conf = cur["mean_conf"] - base["mean_conf"]
    d_tok = cur["tokens"] - base["tokens"]
    if debug:
        print(f"[ocr_quality_gate] Δconf={d_conf:.1f}, Δtok={d_tok}")
    worse = (d_conf < min_delta_conf) or (d_tok < min_delta_tokens)
    return baseline_img if worse else img

# ---------- PNG 무손실 저장 ----------
def save_png_bytes(img: Image.Image, compress_level: int = 6) -> bytes:
    """
    12) PNG 저장(무손실): 텍스트/기호 보존에 유리
    """
    buf = io.BytesIO()
    img.save(buf, format="PNG", optimize=True, compress_level=compress_level)
    return buf.getvalue()

def apply_pipeline(img: Image.Image, steps: Sequence[tuple[Callable, dict]]) -> Image.Image:
    """
    체이닝 실행 유틸. [(func, kwargs), ...] 형태로 전달된 스텝을 순서대로 적용.
    """
    for func, kwargs in steps:
        img = func(img, **kwargs)
    return img

# %%
def preprocess_for_date_extraction(
    img_bytes: bytes,
    # 한국어 OCR을 위한 최적화된 파라미터
    min_long_edge: int = 2000,  # 해상도 더 증가
    target_long_edge: int = 3000,  # 최대 해상도 더 증가
    crop_margin: int = 20,
    autocontrast_cutoff: float = 0.1,  # 대비 더 강화
    sharpen_radius: float = 0.5,
    sharpen_percent: int = 200,  # 샤프닝 더 강화
    sharpen_threshold: int = 1,
    add_border: int = 12,
    png_compress_level: int = 6,
    perspective_padding: int = 8,
    deskew_max_angle: float = 3.0,  # 기울기 보정 완화
    glare_v_high: int = 210,
    glare_s_low: int = 60,
) -> bytes:
    """
    한국어 텍스트 인식에 최적화된 전처리 파이프라인
    """
    try:
        # 1) EXIF 회전 교정
        img = open_with_exif(img_bytes)

        # 체이닝 스텝 구성
        steps: list[tuple[Callable, dict]] = []

        # 2) 투명 채널 플래튼
        steps.append((flatten_transparency, {}))
        
        # 3) 자동 크롭 (마진 증가)
        steps.append((auto_crop_with_margin, dict(margin=crop_margin)))
        
        # 4) 해상도 먼저 증가 (텍스트 선명도 우선)
        steps.append((upscale_min_resolution, dict(min_long_edge=min_long_edge)))
        
        # 5) 조명 평탄화 (한국어 문서에 효과적)
        steps.append((illumination_flatten, dict(blur_ratio=0.03, debug=False)))
        
        # 6) 글레어 억제 강화
        steps.append((suppress_glare, dict(
            v_high=glare_v_high, 
            s_low=glare_s_low, 
            debug=False
        )))
        
        # 7) 투시 보정 (덜 공격적으로)
        steps.append((perspective_unwarp, dict(
            quad=None, 
            keep_aspect=True, 
            padding=perspective_padding, 
            debug=False
        )))
        
        # 8) 데스큐 (더 보수적으로)
        steps.append((deskew_textlines, dict(
            max_angle=deskew_max_angle,
            refine=True,
            refine_range=0.5,
            refine_step=0.02,
            pad=20,
            debug=False
        )))
        
        # 9) 모드 정규화
        steps.append((normalize_mode, {}))
        
        # 10) 대비 강화
        steps.append((weak_autocontrast, dict(cutoff=autocontrast_cutoff)))
        
        # 11) CLAHE 적용 (더 강하게)
        steps.append((apply_clahe, dict(
            clip_limit=2.0, 
            tile_grid=(4,4), 
            enabled=True, 
            debug=False
        )))
        
        # 12) 샤프닝 강화
        steps.append((conservative_sharpen, dict(
            radius=sharpen_radius, 
            percent=sharpen_percent, 
            threshold=sharpen_threshold, 
            enabled=True
        )))
        
        # 13) 그레이스케일 변환
        steps.append((to_grayscale, dict(enabled=True)))
        
        # 14) 테두리 추가 (더 크게)
        steps.append((add_white_border, dict(border=add_border)))
        
        # 15) 타깃 해상도 조정
        steps.append((downscale_target_long_edge, dict(target_long_edge=target_long_edge)))

        # 실행
        img = apply_pipeline(img, steps)

        # PNG 저장
        return save_png_bytes(img, compress_level=png_compress_level)

    except Exception:
        return img_bytes

# %%
class UploadedFileManager:
    def __init__(self):
        # 업로드된 파일들이 저장되는 리스트
        # self.files 의 구조 예시:
        # [
        #     {
        #         "name": "blood_test1.png",       # 파일 이름 (str)
        #         "content": b"...",               # 원본 파일 내용 (bytes)
        #         "io": <_io.BytesIO object>       # BytesIO 객체 (PIL/OpenCV 사용 가능)
        #     },
        #     {
        #         "name": "blood_test2.jpg",
        #         "content": b"...",
        #         "io": <_io.BytesIO object>
        #     }
        # ]
        self.files: List[Dict[str, Any]] = []
    
    def _make_image_record(self, name: str, content: bytes) -> Dict[str, Any]:
        return {"name": name, "content": content, "io": io.BytesIO(content)}
    
    def handler(self, change) -> None:
        """
        ipywidgets FileUpload 위젯의 observe 이벤트 핸들러.

        Args:
            change (dict): ipywidgets 가 observe 이벤트에서 전달하는 dict
                change 의 구조 예시:
                {
                    'name': 'value',                # 변경된 속성 이름
                    'old': (),                      # 이전 값 (tuple of UploadedFile)
                    'new': (                        # 새로운 값 (tuple of UploadedFile)
                        UploadedFile(
                            name='blood_test1.png',
                            type='image/png',
                            size=12345,
                            content=b'...'
                        ),
                        UploadedFile(
                            name='blood_test2.jpg',
                            type='image/jpeg',
                            size=23456,
                            content=b'...'
                        )
                    ),
                    'owner': FileUpload(...)        # 이벤트를 발생시킨 위젯 객체
                }

        Returns:
            None: 반환값은 없으며, self.files 에 업로드된 파일 리스트를 저장합니다.
        """
        try:
            if not change or "new" not in change or not change["new"]:
                self.files = []
                return

            uploaded = list(change["new"])  # tuple of UploadedFile → list 변환
            out: List[Dict[str, Any]] = []

            for f in uploaded:
                name = getattr(f, "name", "uploaded")
                raw_content: bytes = getattr(f, "content", b"")
                mime = getattr(f, "type", "").lower()

                if not raw_content:
                    continue

                is_pdf = name.lower().endswith(".pdf") or mime == "application/pdf"

                # content를 bytes[]로 표준화
                contents: List[bytes] = [raw_content]
                base = os.path.splitext(name)[0]

                if is_pdf:
                    tmp_path = None
                    try:
                        with tempfile.NamedTemporaryFile(suffix=".pdf", delete=False) as tmp:
                            tmp.write(raw_content)
                            tmp_path = tmp.name
                        # PDF → 페이지별 PNG 바이트 리스트
                        contents = pdf_to_images(tmp_path, resolution_scale=2.0)
                    except Exception as e:
                        print(f"❌ PDF 변환 실패({name}): {e}")
                        contents = []
                    finally:
                        if tmp_path and os.path.exists(tmp_path):
                            try:
                                os.remove(tmp_path)
                            except Exception:
                                pass

                # per-image 처리 → out.append
                for i, img_bytes in enumerate(contents, start=1):
                    processed_bytes = preprocess_image_bytes(img_bytes)
                    out_name = f"{base}_p{i:02d}.png" if is_pdf else name
                    
                    # 디버그 저장: 전처리된 이미지를 PNG로 저장
                    try:
                        save_name = out_name if out_name.lower().endswith(".png") else f"{os.path.splitext(out_name)[0]}.png"
                        out_path = os.path.join("debug_output", save_name)
                        with open(out_path, "wb") as fp:
                            fp.write(processed_bytes)
                    except Exception as e:
                        print(f"⚠️ 디버그 저장 실패({out_name}): {e}")

                    out.append(self._make_image_record(out_name, processed_bytes))

            self.files = out
            if self.files:
                print("✅ 업로드 완료:", [f["name"] for f in self.files])
            else:
                print("⚠️ 변환된 파일이 없습니다.")

        except Exception as e:
            print(f"❌ 파일 처리 오류: {e}")
            self.files = []

# %% [markdown]
# ### 3. 검사일자 추출

# %%
def check_tesseract_setup():
    """Tesseract 설치 및 한국어 지원 확인"""
    try:
        import subprocess
        
        # Tesseract 버전 확인
        version_result = subprocess.run(['tesseract', '--version'], 
                                      capture_output=True, text=True)
        print("🔧 Tesseract 버전:")
        print(version_result.stdout.split('\n')[0])
        
        # 지원 언어 확인
        lang_result = subprocess.run(['tesseract', '--list-langs'], 
                                   capture_output=True, text=True)
        available_langs = lang_result.stdout.strip().split('\n')[1:]  # 첫 줄은 헤더
        
        print(f"\n🌐 지원 언어 ({len(available_langs)}개):")
        for lang in available_langs:
            if lang.strip():
                mark = "✅" if lang.strip() in ['kor', 'eng'] else "  "
                print(f"{mark} {lang.strip()}")
        
        # 한국어 지원 확인
        has_korean = 'kor' in available_langs
        has_english = 'eng' in available_langs
        
        print(f"\n📊 언어 지원 상태:")
        print(f"   한국어 (kor): {'✅ 지원' if has_korean else '❌ 미지원'}")
        print(f"   영어 (eng): {'✅ 지원' if has_english else '❌ 미지원'}")
        
        if not has_korean:
            print("\n⚠️ 한국어 언어팩이 설치되지 않음!")
            print("💡 설치 명령어:")
            print("   !apt-get update && apt-get install -y tesseract-ocr-kor")
        
        return has_korean and has_english
        
    except Exception as e:
        print(f"❌ Tesseract 확인 오류: {e}")
        return False

# 테스트 전에 설정 확인
print("🔍 Tesseract 설정 확인:")
check_tesseract_setup()
print("\n" + "="*60)
# Out:
# 🔍 Tesseract 설정 확인:
# 🔧 Tesseract 버전:
# tesseract 4.1.1
#
# 🌐 지원 언어 (3개):
# ✅ eng
# ✅ kor
#    osd
#
# 📊 언어 지원 상태:
#    한국어 (kor): ✅ 지원
#    영어 (eng): ✅ 지원
#
# ============================================================

# %%
import re
from datetime import datetime, date
from typing import Optional, List, Tuple
import pytesseract
from pytesseract import image_to_data, Output
from PIL import Image
import io

def extract_all_text_with_positions(
    processed_image_bytes: bytes,
    lang: str = "kor+eng",
    debug: bool = False
) -> Optional[dict]:
    """
    전처리된 이미지에서 모든 텍스트를 위치정보와 함께 추출
    - 최적화된 단일 OCR 설정 사용
    - TSV 형태로 라인별 정보 포함
    """
    
    try:
        # 이미지 로드
        img = Image.open(io.BytesIO(processed_image_bytes))
        
        if debug:
            print(f"[extract_all_text] 🔍 이미지 크기: {img.size}")
            print(f"[extract_all_text] 🔍 이미지 모드: {img.mode}")
        
        # 최적화된 OCR 설정 (신뢰도가 가장 높은 설정)
        ocr_config = {
            "lang": "kor+eng", 
            "config": "--oem 3 --psm 6"
        }
        
        if debug:
            print(f"[extract_all_text] 🔄 OCR 실행: {ocr_config}")
        
        # image_to_data로 위치정보와 함께 추출 (DICT 형태)
        data = pytesseract.image_to_data(
            img, 
            lang=ocr_config["lang"],
            config=ocr_config["config"],
            output_type=Output.DICT
        )
        
        if debug:
            print(f"[extract_all_text] 📊 OCR 완료 - 총 {len(data.get('text', []))}개 요소 감지")
            print(f"[extract_all_text] 📋 데이터 키: {list(data.keys())}")
        
        # TSV 형태 데이터도 추출 (라인 정보 포함)
        tsv_data = pytesseract.image_to_data(
            img,
            lang=ocr_config["lang"],
            config=ocr_config["config"],
            output_type=Output.STRING
        )
        
        # TSV 파싱
        tsv_lines = []
        if tsv_data:
            lines = tsv_data.strip().split('\n')
            if len(lines) > 1:  # 헤더 제외
                headers = lines[0].split('\t')
                for line in lines[1:]:
                    if line.strip():
                        values = line.split('\t')
                        if len(values) == len(headers):
                            tsv_lines.append(dict(zip(headers, values)))
        
        # 유효한 텍스트만 필터링하여 결과 구성
        valid_items = []
        line_groups = {}  # 라인별 그룹핑
        
        for j in range(len(data.get('text', []))):
            text = (data['text'][j] or "").strip()
            conf = data.get('conf', [0])[j] if j < len(data.get('conf', [])) else 0
            
            # 신뢰도가 0 이상이고 텍스트가 있는 것만
            if text and conf >= 0:
                item = {
                    'text': text,
                    'conf': conf,
                    'left': data.get('left', [0])[j] if j < len(data.get('left', [])) else 0,
                    'top': data.get('top', [0])[j] if j < len(data.get('top', [])) else 0,
                    'width': data.get('width', [0])[j] if j < len(data.get('width', [])) else 0,
                    'height': data.get('height', [0])[j] if j < len(data.get('height', [])) else 0,
                    'level': data.get('level', [0])[j] if j < len(data.get('level', [])) else 0,
                    'page_num': data.get('page_num', [0])[j] if j < len(data.get('page_num', [])) else 0,
                    'block_num': data.get('block_num', [0])[j] if j < len(data.get('block_num', [])) else 0,
                    'par_num': data.get('par_num', [0])[j] if j < len(data.get('par_num', [])) else 0,
                    'line_num': data.get('line_num', [0])[j] if j < len(data.get('line_num', [])) else 0,
                    'word_num': data.get('word_num', [0])[j] if j < len(data.get('word_num', [])) else 0,
                }
                valid_items.append(item)
                
                # 라인별 그룹핑
                line_key = (item['page_num'], item['block_num'], item['par_num'], item['line_num'])
                if line_key not in line_groups:
                    line_groups[line_key] = []
                line_groups[line_key].append(item)
        
        # 라인별 정보 구성
        line_info = []
        for line_key, words in line_groups.items():
            if words:
                # 라인의 바운딩 박스 계산
                left = min(w['left'] for w in words)
                top = min(w['top'] for w in words)
                right = max(w['left'] + w['width'] for w in words)
                bottom = max(w['top'] + w['height'] for w in words)
                
                # 라인 텍스트 결합
                line_text = ' '.join(w['text'] for w in words)
                avg_conf = sum(w['conf'] for w in words) / len(words)
                
                line_info.append({
                    'page_num': line_key[0],
                    'block_num': line_key[1],
                    'par_num': line_key[2],
                    'line_num': line_key[3],
                    'text': line_text,
                    'left': left,
                    'top': top,
                    'width': right - left,
                    'height': bottom - top,
                    'avg_conf': round(avg_conf, 1),
                    'word_count': len(words),
                    'words': words
                })
        
        # 라인 정보를 top 기준으로 정렬
        line_info.sort(key=lambda x: (x['page_num'], x['block_num'], x['par_num'], x['top']))
        
        final_result = {
            'image_info': {
                'size': img.size,
                'mode': img.mode
            },
            'ocr_config': ocr_config,
            'total_valid_items': len(valid_items),
            'total_lines': len(line_info),
            'raw_data': data,          # 전체 원본 DICT 데이터
            'tsv_data': tsv_lines,     # TSV 파싱된 데이터
            'filtered_items': valid_items,  # 필터링된 유효 항목들
            'line_info': line_info     # 라인별 정보
        }
        
        if debug:
            print(f"[extract_all_text] ✅ 유효한 텍스트: {len(valid_items)}개")
            print(f"[extract_all_text] 📝 라인 수: {len(line_info)}개")
            print(f"[extract_all_text] 📄 라인별 텍스트 (최대 10개):")
            for idx, line in enumerate(line_info[:10]):
                print(f"  라인 {idx+1}: '{line['text'][:50]}...' (평균 신뢰도: {line['avg_conf']}, 단어: {line['word_count']}개)")
            
            print(f"[extract_all_text] 📄 단어별 텍스트 샘플 (최대 10개):")
            for idx, item in enumerate(valid_items[:10]):
                print(f"  {idx+1}. '{item['text']}' (신뢰도: {item['conf']}, 위치: {item['left']},{item['top']})")
        
        return final_result
        
    except Exception as e:
        if debug:
            print(f"[extract_all_text] ❌ 오류 발생: {e}")
            import traceback
            traceback.print_exc()
        return None

# %%
import os
import json

print("📂 전처리 및 OCR 테스트")
print("=" * 40)

# 사용자 입력 받기 (data/ 폴더 기본 경로)
filename = input("📄 data/ 폴더 내 파일명을 입력하세요: ").strip()

# 빈 입력 시 기본값 사용
if not filename:
    # filename = "20241121.png"
    filename = "20241107.jpg"
    print(f"🔹 기본 파일 사용: {filename}")

# data/ 경로와 결합
file_path = f"../data/{filename}"
print(f"📁 파일 경로: {file_path}")

# 파일 확장자 확인
file_ext = filename.lower().split(".")[-1]
is_pdf = file_ext == "pdf"
is_image = file_ext in ["png", "jpg", "jpeg", "tiff", "bmp"]

print(f"📋 파일 형식: {file_ext.upper()}")

# 이미지 파일 처리
print("🖼️ 이미지 파일 로드 중...")

try:
    # 파일 읽기
    with open(file_path, "rb") as f:
        raw_image_bytes = f.read()

    print(f"📏 원본 이미지 크기: {len(raw_image_bytes):,} bytes")

    # 전처리 실행
    print("\n🔧 전처리 시작...")
    processed_image_bytes = preprocess_for_date_extraction(raw_image_bytes)

    print(f"📏 전처리된 이미지 크기: {len(processed_image_bytes):,} bytes")

    # 전처리 결과 저장
    output_dir = "debug_output"
    os.makedirs(output_dir, exist_ok=True)

    output_filename = f"preprocessed_{os.path.splitext(filename)[0]}.png"
    output_path = os.path.join(output_dir, output_filename)

    with open(output_path, "wb") as f:
        f.write(processed_image_bytes)

    print(f"💾 전처리 결과 저장: {output_path}")

    # 전처리된 이미지 표시
    from IPython.display import display, Image as IPImage
    display(IPImage(processed_image_bytes))

    print(f"\n✅ 이미지 전처리 완료!")





    # OCR 실행 및 전체 결과 출력
    print("\n🔍 OCR 텍스트 추출 시작...")
    ocr_result = extract_all_text_with_positions(
        processed_image_bytes, 
        debug=True
    )

    if ocr_result:
        print(f"\n📊 OCR 결과 요약:")
        print(f"  - 이미지 크기: {ocr_result['image_info']['size']}")
        print(f"  - OCR 설정: {ocr_result['ocr_config']}")
        print(f"  - 추출된 텍스트 수: {ocr_result['total_valid_items']}")
        print(f"  - 라인 수: {ocr_result['total_lines']}")
        
        # 라인별 결과 출력
        line_info = ocr_result['line_info']
        print(f"\n📝 라인별 텍스트 (총 {len(line_info)}개):")
        print("=" * 100)
        
        for i, line in enumerate(line_info, 1):
            print(f"라인 {i:2d}: '{line['text']}'")
            print(f"        위치: ({line['left']:3d}, {line['top']:3d}) | "
                  f"크기: {line['width']:3d}×{line['height']:3d} | "
                  f"평균 신뢰도: {line['avg_conf']:5.1f} | "
                  f"단어 수: {line['word_count']} | "
                  f"블록: {line['block_num']} | 문단: {line['par_num']} | 라인: {line['line_num']}")
            print()
        
        # 단어별 상세 결과 출력 (선택적)
        print(f"\n📄 단어별 텍스트 상세 (총 {len(ocr_result['filtered_items'])}개):")
        print("=" * 80)
        
        for i, item in enumerate(ocr_result['filtered_items'], 1):
            print(f"{i:3d}. '{item['text']}' ")
            print(f"     신뢰도: {item['conf']:3d} | 위치: ({item['left']:3d}, {item['top']:3d}) | "
                  f"크기: {item['width']:3d}×{item['height']:3d} | "
                  f"레벨: {item['level']} | 블록: {item['block_num']} | "
                  f"문단: {item['par_num']} | 라인: {item['line_num']} | 단어: {item['word_num']}")
            print()
        
        # JSON 파일로 전체 결과 저장
        json_filename = f"ocr_result_{os.path.splitext(filename)[0]}.json"
        json_path = os.path.join(output_dir, json_filename)
        
        with open(json_path, "w", encoding="utf-8") as f:
            json.dump(ocr_result, f, ensure_ascii=False, indent=2)
        
        print(f"💾 OCR 결과 JSON 저장: {json_path}")
        
        # 원본 Tesseract 데이터 구조 출력
        print(f"\n🔍 원본 Tesseract 데이터 구조:")
        raw_data = ocr_result['raw_data']
        print(f"DICT 데이터 키: {list(raw_data.keys())}")
        for key in raw_data.keys():
            print(f"  {key}: {len(raw_data[key])}개 항목")
        
        print(f"\nTSV 데이터 샘플 (최대 5개):")
        for i, tsv_item in enumerate(ocr_result['tsv_data'][:5]):
            print(f"  TSV {i+1}: {tsv_item}")




except FileNotFoundError:
    print(f"❌ 파일을 찾을 수 없습니다: {file_path}")
except Exception as e:
    print(f"❌ 오류: {e}")
    import traceback
    traceback.print_exc()
# Out:
# 📂 전처리 및 OCR 테스트
# ========================================
# 🔹 기본 파일 사용: 20241107.jpg
# 📁 파일 경로: ../data/20241107.jpg
# 📋 파일 형식: JPG
# 🖼️ 이미지 파일 로드 중...
# 📏 원본 이미지 크기: 213,793 bytes
#
# 🔧 전처리 시작...
# 📏 전처리된 이미지 크기: 647,570 bytes
# 💾 전처리 결과 저장: debug_output/preprocessed_20241107.png
# ✅ 이미지 전처리 완료!
#
# 🔍 OCR 텍스트 추출 시작...
# [extract_all_text] 🔍 이미지 크기: (1441, 2024)
# [extract_all_text] 🔍 이미지 모드: L
# [extract_all_text] 🔄 OCR 실행: {'lang': 'kor+eng', 'config': '--oem 3 --psm 6'}
# [extract_all_text] 📊 OCR 완료 - 총 340개 요소 감지
# [extract_all_text] 📋 데이터 키: ['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text']
# [extract_all_text] ✅ 유효한 텍스트: 287개
# [extract_all_text] 📝 라인 수: 50개
# [extract_all_text] 📄 라인별 텍스트 (최대 10개):
#   라인 1: 'LYMPHO, 20. Tess...' (평균 신뢰도: 6.3, 단어: 3개)
#   라인 2: '40000 121 를...' (평균 신뢰도: 28.0, 단어: 3개)
#   라인 3: '20500 0.1%...' (평균 신뢰도: 47.5, 단어: 2개)
#   라인 4: 'BASO (a) 00 2...' (평균 신뢰도: 82.5, 단어: 4개)
#   라인 5: 'NEUE 115-1029 10.22 ¥ ELL mT...' (평균 신뢰도: 54.7, 단어: 6개)
#   라인 6: 'LYMPH 317 KA LL) a ee [TT...' (평균 신뢰도: 51.0, 단어: 7개)
#   라인 7: '| MONO 005 067 135 Khu EET Ce...' (평균 신뢰도: 62.5, 단어: 8개)
#   라인 8: '|| Eos 017 157 0.02 Ka Le CES...' (평균 신뢰도: 51.5, 단어: 8개)
#   라인 9: '| BAS. 0010.26 0.03 Ki Co [111...' (평균 신뢰도: 52.3, 단어: 7개)
#   라인 10: '|p os 200 니크...' (평균 신뢰도: 39.0, 단어: 4개)
# [extract_all_text] 📄 단어별 텍스트 샘플 (최대 10개):
#   1. 'LYMPHO,' (신뢰도: 4, 위치: 84,138)
#   2. '20.' (신뢰도: 0, 위치: 599,152)
#   3. 'Tess' (신뢰도: 15, 위치: 678,152)
#   4. '40000' (신뢰도: 8, 위치: 86,172)
#   5. '121' (신뢰도: 64, 위치: 603,186)
#   6. '를' (신뢰도: 12, 위치: 680,181)
#   7. '20500' (신뢰도: 43, 위치: 84,210)
#   8. '0.1%' (신뢰도: 52, 위치: 608,217)
#   9. 'BASO' (신뢰도: 92, 위치: 84,240)
#   10. '(a)' (신뢰도: 79, 위치: 143,245)
#
# 📊 OCR 결과 요약:
#   - 이미지 크기: (1441, 2024)
#   - OCR 설정: {'lang': 'kor+eng', 'config': '--oem 3 --psm 6'}
#   - 추출된 텍스트 수: 287
#   - 라인 수: 50
#
# 📝 라인별 텍스트 (총 50개):
# ====================================================================================================
# 라인  1: 'LYMPHO, 20. Tess'
#         위치: ( 84, 138) | 크기: 617× 44 | 평균 신뢰도:   6.3 | 단어 수: 3 | 블록: 1 | 문단: 1 | 라인: 1
#
# 라인  2: '40000 121 를'
#         위치: ( 86, 172) | 크기: 617× 49 | 평균 신뢰도:  28.0 | 단어 수: 3 | 블록: 1 | 문단: 1 | 라인: 2
#
# 라인  3: '20500 0.1%'
#         위치: ( 84, 210) | 크기: 619× 41 | 평균 신뢰도:  47.5 | 단어 수: 2 | 블록: 1 | 문단: 1 | 라인: 3
#
# 라인  4: 'BASO (a) 00 2'
#         위치: ( 84, 240) | 크기: 619× 45 | 평균 신뢰도:  82.5 | 단어 수: 4 | 블록: 1 | 문단: 1 | 라인: 4
#
# 라인  5: 'NEUE 115-1029 10.22 ¥ ELL mT'
#         위치: ( 76, 272) | 크기: 1170× 50 | 평균 신뢰도:  54.7 | 단어 수: 6 | 블록: 1 | 문단: 1 | 라인: 5
#
# 라인  6: 'LYMPH 317 KA LL) a ee [TT'
#         위치: ( 84, 307) | 크기: 1178× 52 | 평균 신뢰도:  51.0 | 단어 수: 7 | 블록: 1 | 문단: 1 | 라인: 6
#
# 라인  7: '| MONO 005 067 135 Khu EET Ce'
#         위치: ( 69, 344) | 크기: 1206× 49 | 평균 신뢰도:  62.5 | 단어 수: 8 | 블록: 1 | 문단: 1 | 라인: 7
#
# 라인  8: '|| Eos 017 157 0.02 Ka Le CES'
#         위치: ( 68, 382) | 크기: 1195× 44 | 평균 신뢰도:  51.5 | 단어 수: 8 | 블록: 1 | 문단: 1 | 라인: 8
#
# 라인  9: '| BAS. 0010.26 0.03 Ki Co [111'
#         위치: ( 69, 415) | 크기: 1182× 46 | 평균 신뢰도:  52.3 | 단어 수: 7 | 블록: 1 | 문단: 1 | 라인: 9
#
# 라인 10: '|p os 200 니크'
#         위치: ( 69, 420) | 크기: 1181× 74 | 평균 신뢰도:  39.0 | 단어 수: 4 | 블록: 1 | 문단: 1 | 라인: 10
#
# 라인 11: '002" 22.5 0'
#         위치: ( 80, 483) | 크기: 594× 42 | 평균 신뢰도:  43.3 | 단어 수: 3 | 블록: 1 | 문단: 1 | 라인: 11
#
# 라인 12: '| PDW 요'
#         위치: ( 69, 527) | 크기: 632× 30 | 평균 신뢰도:  62.7 | 단어 수: 3 | 블록: 1 | 문단: 1 | 라인: 12
#
# 라인 13: '|? 027% -'
#         위치: ( 69, 557) | 크기: 839× 40 | 평균 신뢰도:  53.3 | 단어 수: 3 | 블록: 1 | 문단: 1 | 라인: 13
#
# 라인 14: '|| RETHGB 32 -20.8 Pldi ep el.) | Cer |'
#         위치: ( 65, 589) | 크기: 1295× 41 | 평균 신뢰도:  28.9 | 단어 수: 10 | 블록: 1 | 문단: 1 | 라인: 14
#
# 라인 15: '렬 액 형 검 사 (고양이 키트'
#         위치: ( 78, 629) | 크기: 252× 53 | 평균 신뢰도:  84.3 | 단어 수: 7 | 블록: 1 | 문단: 1 | 라인: 15
#
# 라인 16: '|| Name Reference NINN Result Unit (5 |'
#         위치: ( 69, 678) | 크기: 1289× 45 | 평균 신뢰도:  50.9 | 단어 수: 8 | 블록: 1 | 문단: 1 | 라인: 16
#
# 라인 17: 'ea)'
#         위치: (658, 725) | 크기: 702× 32 | 평균 신뢰도:  31.0 | 단어 수: 1 | 블록: 1 | 문단: 1 | 라인: 17
#
# 라인 18: 'ProBNP-feline(Snapshot, nt-proBNP) kit 제'
#         위치: ( 74, 775) | 크기: 1281× 30 | 평균 신뢰도:  63.2 | 단어 수: 4 | 블록: 1 | 문단: 1 | 라인: 18
#
# 라인 19: '| Name Reference EE Result Unit'
#         위치: ( 69, 808) | 크기: 632× 40 | 평균 신뢰도:  63.7 | 단어 수: 6 | 블록: 1 | 문단: 1 | 라인: 19
#
# 라인 20: 're'
#         위치: (1177, 812) | 크기: 151×150 | 평균 신뢰도:  23.0 | 단어 수: 1 | 블록: 1 | 문단: 1 | 라인: 20
#
# 라인 21: 'NT-proBNP Bt pol | | |) a | | | ! |'
#         위치: ( 84, 876) | 크기: 1274× 47 | 평균 신뢰도:  56.2 | 단어 수: 12 | 블록: 1 | 문단: 1 | 라인: 21
#
# 라인 22: '검사 - 혈 압 즉 정 (의리 Ｌ ㄴ ㅎ'
#         위치: ( 88, 933) | 크기: 268× 40 | 평균 신뢰도:  44.9 | 단어 수: 10 | 블록: 1 | 문단: 1 | 라인: 22
#
# 라인 23: '5 스 = 즈 르 |'
#         위치: ( 68, 967) | 크기: 1292× 55 | 평균 신뢰도:  39.7 | 단어 수: 6 | 블록: 1 | 문단: 1 | 라인: 23
#
# 라인 24: 'ㆍ ㅎㅎ ㅣ'
#         위치: (626, 1005) | 크기: 728× 57 | 평균 신뢰도:  54.7 | 단어 수: 3 | 블록: 1 | 문단: 1 | 라인: 24
#
# 라인 25: '‘Laboratory date’ 2024-11-07'
#         위치: ( 75, 1070) | 크기: 270× 40 | 평균 신뢰도:  77.7 | 단어 수: 3 | 블록: 1 | 문단: 1 | 라인: 25
#
# 라인 26: 'SAA Procyte Brat (CBO) Viral = ^“'
#         위치: ( 88, 1101) | 크기: 1264× 47 | 평균 신뢰도:  43.3 | 단어 수: 7 | 블록: 1 | 문단: 1 | 라인: 26
#
# 라인 27: '|'
#         위치: (1357, 1146) | 크기:   3× 24 | 평균 신뢰도:  61.0 | 단어 수: 1 | 블록: 1 | 문단: 1 | 라인: 27
#
# 라인 28: 'RB 6542122 2.18 Mila Ml dole] ia'
#         위치: ( 68, 1179) | 크기: 1257× 47 | 평균 신뢰도:  48.4 | 단어 수: 7 | 블록: 1 | 문단: 1 | 라인: 28
#
# 라인 29: 'HCH 303 523 226 | 1 | [11'
#         위치: ( 84, 1218) | 크기: 1169× 40 | 평균 신뢰도:  66.1 | 단어 수: 8 | 블록: 1 | 문단: 1 | 라인: 29
#
# 라인 30: 'HGB 982162 94 GI 11 그'
#         위치: ( 84, 1251) | 크기: 1169× 44 | 평균 신뢰도:  61.7 | 단어 수: 6 | 블록: 1 | 문단: 1 | 라인: 30
#
# 라인 31: 'MCV 376 0. Or) ) ! 117'
#         위치: ( 83, 1284) | 크기: 1171× 45 | 평균 신뢰도:  53.9 | 단어 수: 7 | 블록: 1 | 문단: 1 | 라인: 31
#
# 라인 32: 'MCH 11.8173 18 re =. oon'
#         위치: ( 69, 1319) | 크기: 1184× 44 | 평균 신뢰도:  45.2 | 단어 수: 6 | 블록: 1 | 문단: 1 | 라인: 32
#
# 라인 33: 'MCHC 28.1-35.8 as a Eo 1'
#         위치: ( 72, 1321) | 크기: 1181× 82 | 평균 신뢰도:  48.3 | 단어 수: 6 | 블록: 1 | 문단: 1 | 라인: 33
#
# 라인 34: 'RDW 15-27 23.5% Mo 11 | |_| | | |'
#         위치: ( 70, 1388) | 크기: 1183× 42 | 평균 신뢰도:  63.2 | 단어 수: 10 | 블록: 1 | 문단: 1 | 라인: 34
#
# 라인 35: 'Relics?) 0.0% ='
#         위치: ( 73, 1421) | 크기: 1012× 42 | 평균 신뢰도:  42.7 | 단어 수: 3 | 블록: 1 | 문단: 1 | 라인: 35
#
# 라인 36: 'RETIC 3-50 09 KAL 1 | ㅎㅎㅎ ㄴㄴ | | Ｌ'
#         위치: ( 69, 1454) | 크기: 1184× 42 | 평균 신뢰도:  65.5 | 단어 수: 11 | 블록: 1 | 문단: 1 | 라인: 36
#
# 라인 37: '4 … ~ ee'
#         위치: (406, 1486) | 크기: 850× 18 | 평균 신뢰도:  41.5 | 단어 수: 4 | 블록: 1 | 문단: 1 | 라인: 37
#
# 라인 38: 'WEG … 15.01 Kab | | | 베 페 | | |'
#         위치: ( 79, 1489) | 크기: 1170× 44 | 평균 신뢰도:  58.2 | 단어 수: 12 | 블록: 1 | 문단: 1 | 라인: 38
#
# 라인 39: '26018080808900 그 ='
#         위치: ( 70, 1523) | 크기: 1067× 50 | 평균 신뢰도:  43.7 | 단어 수: 3 | 블록: 1 | 문단: 1 | 라인: 39
#
# 라인 40: '00000 2'
#         위치: ( 89, 1543) | 크기: 557× 77 | 평균 신뢰도:  24.0 | 단어 수: 2 | 블록: 1 | 문단: 1 | 라인: 40
#
# 라인 41: '346000( 48%'
#         위치: ( 84, 1596) | 크기: 619× 44 | 평균 신뢰도:  47.5 | 단어 수: 2 | 블록: 1 | 문단: 1 | 라인: 41
#
# 라인 42: 'EOS(%) 05%'
#         위치: ( 68, 1628) | 크기: 635× 46 | 평균 신뢰도:  43.5 | 단어 수: 2 | 블록: 1 | 문단: 1 | 라인: 42
#
# 라인 43: 'BASO (a) 6'
#         위치: ( 84, 1666) | 크기: 620× 35 | 평균 신뢰도:  53.7 | 단어 수: 3 | 블록: 1 | 문단: 1 | 라인: 43
#
# 라인 44: '1601 115-1029 10.7 Ku A] | eT | |'
#         위치: ( 86, 1691) | 크기: 1163× 52 | 평균 신뢰도:  46.4 | 단어 수: 9 | 블록: 1 | 문단: 1 | 라인: 44
#
# 라인 45: 'Ee 005 00 이그 2 | a TT'
#         위치: ( 78, 1735) | 크기: 1175×165 | 평균 신뢰도:  29.5 | 단어 수: 8 | 블록: 1 | 문단: 1 | 라인: 46
#
# 라인 46: 'LYMPH) 0.92 -6.88 3.43 Kh ie 로 [그'
#         위치: ( 83, 1736) | 크기: 1167× 43 | 평균 신뢰도:  33.8 | 단어 수: 8 | 블록: 1 | 문단: 1 | 라인: 45
#
# 라인 47: 'Eos Dato ae [1] ees TTT'
#         위치: ( 84, 1805) | 크기: 1171× 54 | 평균 신뢰도:  25.2 | 단어 수: 6 | 블록: 1 | 문단: 1 | 라인: 47
#
# 라인 48: 'BASO 001-026 10.01 Ki 1 11 CELL'
#         위치: ( 84, 1838) | 크기: 1166× 44 | 평균 신뢰도:  48.4 | 단어 수: 7 | 블록: 1 | 문단: 1 | 라인: 48
#
# 라인 49: '| PLT) 151-000 8 KAD | | ㅣ | ㅣ | 14 ㅣ'
#         위치: ( 78, 1855) | 크기: 1280× 59 | 평균 신뢰도:  46.3 | 단어 수: 13 | 블록: 1 | 문단: 1 | 라인: 49
#
# 라인 50: '024-11.07.2 = 04-09) Page:'
#         위치: ( 81, 1923) | 크기: 1242× 44 | 평균 신뢰도:  65.0 | 단어 수: 4 | 블록: 1 | 문단: 1 | 라인: 50
#
#
# 📄 단어별 텍스트 상세 (총 287개):
# ================================================================================
#   1. 'LYMPHO,'
#      신뢰도:   4 | 위치: ( 84, 138) | 크기: 122× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 1 | 단어: 1
#
#   2. '20.'
#      신뢰도:   0 | 위치: (599, 152) | 크기:  45× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 1 | 단어: 2
#
#   3. 'Tess'
#      신뢰도:  15 | 위치: (678, 152) | 크기:  23× 19 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 1 | 단어: 3
#
#   4. '40000'
#      신뢰도:   8 | 위치: ( 86, 172) | 크기:  71× 49 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 2 | 단어: 1
#
#   5. '121'
#      신뢰도:  64 | 위치: (603, 186) | 크기:  38× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 2 | 단어: 2
#
#   6. '를'
#      신뢰도:  12 | 위치: (680, 181) | 크기:  23× 28 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 2 | 단어: 3
#
#   7. '20500'
#      신뢰도:  43 | 위치: ( 84, 210) | 크기:  76× 41 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 3 | 단어: 1
#
#   8. '0.1%'
#      신뢰도:  52 | 위치: (608, 217) | 크기:  95× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 3 | 단어: 2
#
#   9. 'BASO'
#      신뢰도:  92 | 위치: ( 84, 240) | 크기:  53× 45 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 4 | 단어: 1
#
#  10. '(a)'
#      신뢰도:  79 | 위치: (143, 245) | 크기:  39× 32 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 4 | 단어: 2
#
#  11. '00'
#      신뢰도:  87 | 위치: (610, 252) | 크기:  34× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 4 | 단어: 3
#
#  12. '2'
#      신뢰도:  72 | 위치: (680, 252) | 크기:  23× 29 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 4 | 단어: 4
#
#  13. 'NEUE'
#      신뢰도:  60 | 위치: ( 76, 272) | 크기:  70× 48 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 5 | 단어: 1
#
#  14. '115-1029'
#      신뢰도:  79 | 위치: (332, 274) | 크기: 100× 46 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 5 | 단어: 2
#
#  15. '10.22'
#      신뢰도:  92 | 위치: (586, 275) | 크기:  55× 47 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 5 | 단어: 3
#
#  16. '¥'
#      신뢰도:   8 | 위치: (648, 282) | 크기:  13× 36 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 5 | 단어: 4
#
#  17. 'ELL'
#      신뢰도:  46 | 위치: (781, 288) | 크기:  74× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 5 | 단어: 5
#
#  18. 'mT'
#      신뢰도:  43 | 위치: (1137, 287) | 크기: 109× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 5 | 단어: 6
#
#  19. 'LYMPH'
#      신뢰도:  93 | 위치: ( 84, 310) | 크기:  83× 47 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 6 | 단어: 1
#
#  20. '317'
#      신뢰도:  71 | 위치: (603, 318) | 크기:  44× 41 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 6 | 단어: 2
#
#  21. 'KA'
#      신뢰도:  71 | 위치: (656, 315) | 크기:  21× 29 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 6 | 단어: 3
#
#  22. 'LL)'
#      신뢰도:  42 | 위치: (777, 317) | 크기:  78× 37 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 6 | 단어: 4
#
#  23. 'a'
#      신뢰도:  17 | 위치: (869, 311) | 크기: 261× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 6 | 단어: 5
#
#  24. 'ee'
#      신뢰도:  38 | 위치: (1106, 307) | 크기:  53× 52 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 6 | 단어: 6
#
#  25. '[TT'
#      신뢰도:  25 | 위치: (1165, 318) | 크기:  97× 36 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 6 | 단어: 7
#
#  26. '|'
#      신뢰도:  94 | 위치: ( 69, 373) | 크기:   1× 15 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 7 | 단어: 1
#
#  27. 'MONO'
#      신뢰도:  60 | 위치: ( 84, 357) | 크기:  68× 33 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 7 | 단어: 2
#
#  28. '005'
#      신뢰도:  81 | 위치: (340, 357) | 크기:  30× 24 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 7 | 단어: 3
#
#  29. '067'
#      신뢰도:  81 | 위치: (387, 357) | 크기:  50× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 7 | 단어: 4
#
#  30. '135'
#      신뢰도:  70 | 위치: (603, 356) | 크기:  66× 37 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 7 | 단어: 5
#
#  31. 'Khu'
#      신뢰도:  56 | 위치: (687, 382) | 크기:   3×  8 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 7 | 단어: 6
#
#  32. 'EET'
#      신뢰도:  25 | 위치: (777, 357) | 크기:  78× 20 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 7 | 단어: 7
#
#  33. 'Ce'
#      신뢰도:  33 | 위치: (1165, 344) | 크기: 110× 47 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 7 | 단어: 8
#
#  34. '||'
#      신뢰도:  68 | 위치: ( 68, 383) | 크기:  15× 42 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 8 | 단어: 1
#
#  35. 'Eos'
#      신뢰도:  93 | 위치: ( 86, 392) | 크기:  38× 29 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 8 | 단어: 2
#
#  36. '017'
#      신뢰도:  39 | 위치: (339, 388) | 크기:  41× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 8 | 단어: 3
#
#  37. '157'
#      신뢰도:  70 | 위치: (399, 386) | 크기:  37× 28 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 8 | 단어: 4
#
#  38. '0.02'
#      신뢰도:  73 | 위치: (601, 382) | 크기:  42× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 8 | 단어: 5
#
#  39. 'Ka'
#      신뢰도:  35 | 위치: (648, 392) | 크기:  41× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 8 | 단어: 6
#
#  40. 'Le'
#      신뢰도:  29 | 위치: (777, 391) | 크기:  27× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 8 | 단어: 7
#
#  41. 'CES'
#      신뢰도:   5 | 위치: (1165, 392) | 크기:  98× 20 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 8 | 단어: 8
#
#  42. '|'
#      신뢰도:  58 | 위치: ( 69, 423) | 크기:   1× 16 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 9 | 단어: 1
#
#  43. 'BAS.'
#      신뢰도:  66 | 위치: ( 84, 420) | 크기:  62× 24 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 9 | 단어: 2
#
#  44. '0010.26'
#      신뢰도:  30 | 위치: (340, 421) | 크기:  92× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 9 | 단어: 3
#
#  45. '0.03'
#      신뢰도:  76 | 위치: (602, 421) | 크기:  58× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 9 | 단어: 4
#
#  46. 'Ki'
#      신뢰도:  20 | 위치: (647, 415) | 크기:  36× 46 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 9 | 단어: 5
#
#  47. 'Co'
#      신뢰도:  54 | 위치: (783, 426) | 크기:  46× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 9 | 단어: 6
#
#  48. '[111'
#      신뢰도:  62 | 위치: (1165, 415) | 크기:  86× 32 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 9 | 단어: 7
#
#  49. '|p'
#      신뢰도:  48 | 위치: ( 69, 442) | 크기:  31× 52 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 10 | 단어: 1
#
#  50. 'os'
#      신뢰도:  13 | 위치: (384, 420) | 크기:  55× 64 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 10 | 단어: 2
#
#  51. '200'
#      신뢰도:  37 | 위치: (610, 448) | 크기:  83× 34 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 10 | 단어: 3
#
#  52. '니크'
#      신뢰도:  58 | 위치: (1165, 453) | 크기:  85× 28 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 10 | 단어: 4
#
#  53. '002"'
#      신뢰도:  56 | 위치: ( 80, 484) | 크기:  54× 41 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 11 | 단어: 1
#
#  54. '22.5'
#      신뢰도:  62 | 위치: (603, 487) | 크기:  41× 27 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 11 | 단어: 2
#
#  55. '0'
#      신뢰도:  12 | 위치: (650, 483) | 크기:  24× 36 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 11 | 단어: 3
#
#  56. '|'
#      신뢰도:  52 | 위치: ( 69, 530) | 크기:   1× 17 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 12 | 단어: 1
#
#  57. 'PDW'
#      신뢰도:  79 | 위치: ( 84, 530) | 크기:  50× 27 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 12 | 단어: 2
#
#  58. '요'
#      신뢰도:  57 | 위치: (678, 527) | 크기:  23× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 12 | 단어: 3
#
#  59. '|?'
#      신뢰도:  47 | 위치: ( 69, 564) | 크기:   1×  3 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 13 | 단어: 1
#
#  60. '027%'
#      신뢰도:  52 | 위치: (603, 557) | 크기: 100× 29 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 13 | 단어: 2
#
#  61. '-'
#      신뢰도:  61 | 위치: (884, 586) | 크기:  24× 11 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 13 | 단어: 3
#
#  62. '||'
#      신뢰도:  41 | 위치: ( 65, 589) | 크기:  19× 38 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 14 | 단어: 1
#
#  63. 'RETHGB'
#      신뢰도:  44 | 위치: ( 84, 589) | 크기:  89× 38 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 14 | 단어: 2
#
#  64. '32'
#      신뢰도:   8 | 위치: (358, 598) | 크기:  41× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 14 | 단어: 3
#
#  65. '-20.8'
#      신뢰도:   8 | 위치: (409, 599) | 크기:  23× 18 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 14 | 단어: 4
#
#  66. 'Pldi'
#      신뢰도:   2 | 위치: (584, 621) | 크기:  57×  1 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 14 | 단어: 5
#
#  67. 'ep'
#      신뢰도:  51 | 위치: (648, 602) | 크기:  54× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 14 | 단어: 6
#
#  68. 'el.)'
#      신뢰도:   6 | 위치: (757, 599) | 크기:  98× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 14 | 단어: 7
#
#  69. '|'
#      신뢰도:  51 | 위치: (822, 589) | 크기:  22× 41 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 14 | 단어: 8
#
#  70. 'Cer'
#      신뢰도:  25 | 위치: (1165, 599) | 크기: 172× 24 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 14 | 단어: 9
#
#  71. '|'
#      신뢰도:  53 | 위치: (1357, 618) | 크기:   3×  8 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 14 | 단어: 10
#
#  72. '렬'
#      신뢰도:  67 | 위치: ( 78, 645) | 크기:  33× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 15 | 단어: 1
#
#  73. '액'
#      신뢰도:  83 | 위치: ( 90, 629) | 크기:  41× 53 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 15 | 단어: 2
#
#  74. '형'
#      신뢰도:  87 | 위치: (122, 645) | 크기:  20× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 15 | 단어: 3
#
#  75. '검'
#      신뢰도:  93 | 위치: (144, 637) | 크기:  33× 31 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 15 | 단어: 4
#
#  76. '사'
#      신뢰도:  93 | 위치: (166, 629) | 크기:  21× 53 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 15 | 단어: 5
#
#  77. '(고양이'
#      신뢰도:  75 | 위치: (176, 633) | 크기: 150× 37 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 15 | 단어: 6
#
#  78. '키트'
#      신뢰도:  92 | 위치: (269, 629) | 크기:  61× 53 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 15 | 단어: 7
#
#  79. '||'
#      신뢰도:  66 | 위치: ( 69, 692) | 크기:   1× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 16 | 단어: 1
#
#  80. 'Name'
#      신뢰도:  33 | 위치: ( 84, 678) | 크기:  56× 45 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 16 | 단어: 2
#
#  81. 'Reference'
#      신뢰도:  31 | 위치: (331, 678) | 크기: 106× 45 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 16 | 단어: 3
#
#  82. 'NINN'
#      신뢰도:  23 | 위치: (443, 678) | 크기: 102× 45 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 16 | 단어: 4
#
#  83. 'Result'
#      신뢰도:  46 | 위치: (579, 678) | 크기:  64× 45 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 16 | 단어: 5
#
#  84. 'Unit'
#      신뢰도:  88 | 위치: (658, 678) | 크기:  43× 45 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 16 | 단어: 6
#
#  85. '(5'
#      신뢰도:  27 | 위치: (706, 678) | 크기:  87× 45 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 16 | 단어: 7
#
#  86. '|'
#      신뢰도:  93 | 위치: (1357, 686) | 크기:   1× 28 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 16 | 단어: 8
#
#  87. 'ea)'
#      신뢰도:  31 | 위치: (658, 725) | 크기: 702× 32 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 17 | 단어: 1
#
#  88. 'ProBNP-feline(Snapshot,'
#      신뢰도:   5 | 위치: ( 74, 775) | 크기: 248× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 18 | 단어: 1
#
#  89. 'nt-proBNP)'
#      신뢰도:  81 | 위치: (323, 778) | 크기: 110× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 18 | 단어: 2
#
#  90. 'kit'
#      신뢰도:  92 | 위치: (438, 775) | 크기:  32× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 18 | 단어: 3
#
#  91. '제'
#      신뢰도:  75 | 위치: (1346, 804) | 크기:   9×  1 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 18 | 단어: 4
#
#  92. '|'
#      신뢰도:  78 | 위치: ( 69, 821) | 크기:   1× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 19 | 단어: 1
#
#  93. 'Name'
#      신뢰도:  38 | 위치: ( 73, 808) | 크기:  74× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 19 | 단어: 2
#
#  94. 'Reference'
#      신뢰도:  86 | 위치: (333, 808) | 크기: 104× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 19 | 단어: 3
#
#  95. 'EE'
#      신뢰도:  30 | 위치: (513, 808) | 크기:  64× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 19 | 단어: 4
#
#  96. 'Result'
#      신뢰도:  93 | 위치: (580, 818) | 크기:  63× 18 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 19 | 단어: 5
#
#  97. 'Unit'
#      신뢰도:  57 | 위치: (658, 818) | 크기:  43× 18 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 19 | 단어: 6
#
#  98. 're'
#      신뢰도:  23 | 위치: (1177, 812) | 크기: 151×150 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 20 | 단어: 1
#
#  99. 'NT-proBNP'
#      신뢰도:  53 | 위치: ( 84, 876) | 크기: 115× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 1
#
# 100. 'Bt'
#      신뢰도:  44 | 위치: (387, 893) | 크기:  26× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 2
#
# 101. 'pol'
#      신뢰도:  43 | 위치: (654, 893) | 크기:  47× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 3
#
# 102. '|'
#      신뢰도:  88 | 위치: (773, 896) | 크기:  23× 20 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 4
#
# 103. '|'
#      신뢰도:  95 | 위치: (808, 896) | 크기:  13× 17 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 5
#
# 104. '|)'
#      신뢰도:  46 | 위치: (826, 879) | 크기:  11× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 6
#
# 105. 'a'
#      신뢰도:   7 | 위치: (834, 883) | 크기: 429× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 7
#
# 106. '|'
#      신뢰도:  34 | 위치: (1181, 879) | 크기:  16× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 8
#
# 107. '|'
#      신뢰도:  84 | 위치: (1205, 879) | 크기:  17× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 9
#
# 108. '|'
#      신뢰도:  68 | 위치: (1222, 879) | 크기:  22× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 10
#
# 109. '!'
#      신뢰도:  71 | 위치: (1244, 879) | 크기:  22× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 11
#
# 110. '|'
#      신뢰도:  42 | 위치: (1357, 905) | 크기:   1×  9 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 21 | 단어: 12
#
# 111. '검사'
#      신뢰도:  69 | 위치: ( 88, 933) | 크기:  41× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 22 | 단어: 1
#
# 112. '-'
#      신뢰도:  69 | 위치: (129, 933) | 크기:   5× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 22 | 단어: 2
#
# 113. '혈'
#      신뢰도:  85 | 위치: (131, 937) | 크기:  51× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 22 | 단어: 3
#
# 114. '압'
#      신뢰도:  90 | 위치: (189, 940) | 크기:  15× 22 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 22 | 단어: 4
#
# 115. '즉'
#      신뢰도:  42 | 위치: (211, 940) | 크기:  16× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 22 | 단어: 5
#
# 116. '정'
#      신뢰도:  93 | 위치: (219, 933) | 크기:  15× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 22 | 단어: 6
#
# 117. '(의리'
#      신뢰도:   1 | 위치: (226, 937) | 크기:  67× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 22 | 단어: 7
#
# 118. 'Ｌ'
#      신뢰도:   0 | 위치: (331, 933) | 크기:   6× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 22 | 단어: 8
#
# 119. 'ㄴ'
#      신뢰도:   0 | 위치: (336, 965) | 크기:   3×  1 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 22 | 단어: 9
#
# 120. 'ㅎ'
#      신뢰도:   0 | 위치: (343, 965) | 크기:  13×  1 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 22 | 단어: 10
#
# 121. '5'
#      신뢰도:  67 | 위치: ( 68, 984) | 크기:   2× 22 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 23 | 단어: 1
#
# 122. '스'
#      신뢰도:   0 | 위치: (411, 967) | 크기:  49× 55 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 23 | 단어: 2
#
# 123. '='
#      신뢰도:  14 | 위치: (486, 967) | 크기:  84× 55 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 23 | 단어: 3
#
# 124. '즈'
#      신뢰도:  12 | 위치: (569, 967) | 크기:  90× 55 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 23 | 단어: 4
#
# 125. '르'
#      신뢰도:  59 | 위치: (614, 973) | 크기: 104× 35 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 23 | 단어: 5
#
# 126. '|'
#      신뢰도:  86 | 위치: (1333, 971) | 크기:  27× 34 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 23 | 단어: 6
#
# 127. 'ㆍ'
#      신뢰도:  38 | 위치: (626, 1009) | 크기:   1× 29 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 24 | 단어: 1
#
# 128. 'ㅎㅎ'
#      신뢰도:  63 | 위치: (908, 1005) | 크기: 172× 57 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 24 | 단어: 2
#
# 129. 'ㅣ'
#      신뢰도:  63 | 위치: (1332, 1005) | 크기:  22× 57 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 24 | 단어: 3
#
# 130. '‘Laboratory'
#      신뢰도:  79 | 위치: ( 75, 1077) | 크기: 101× 20 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 25 | 단어: 1
#
# 131. 'date’'
#      신뢰도:  64 | 위치: (178, 1072) | 크기:  54× 34 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 25 | 단어: 2
#
# 132. '2024-11-07'
#      신뢰도:  90 | 위치: (254, 1070) | 크기:  91× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 25 | 단어: 3
#
# 133. 'SAA'
#      신뢰도:  43 | 위치: ( 88, 1108) | 크기:  72× 34 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 26 | 단어: 1
#
# 134. 'Procyte'
#      신뢰도:  85 | 위치: (167, 1101) | 크기:  83× 47 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 26 | 단어: 2
#
# 135. 'Brat'
#      신뢰도:   0 | 위치: (249, 1106) | 크기:  87× 36 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 26 | 단어: 3
#
# 136. '(CBO)'
#      신뢰도:  55 | 위치: (340, 1101) | 크기:  62× 47 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 26 | 단어: 4
#
# 137. 'Viral'
#      신뢰도:  36 | 위치: (405, 1101) | 크기:  88× 47 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 26 | 단어: 5
#
# 138. '='
#      신뢰도:  35 | 위치: (495, 1111) | 크기:  24× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 26 | 단어: 6
#
# 139. '^“'
#      신뢰도:  49 | 위치: (678, 1141) | 크기: 674×  1 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 26 | 단어: 7
#
# 140. '|'
#      신뢰도:  61 | 위치: (1357, 1146) | 크기:   3× 24 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 27 | 단어: 1
#
# 141. 'RB'
#      신뢰도:  89 | 위치: ( 68, 1179) | 크기:  45× 46 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 28 | 단어: 1
#
# 142. '6542122'
#      신뢰도:  43 | 위치: (320, 1188) | 크기: 120× 35 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 28 | 단어: 2
#
# 143. '2.18'
#      신뢰도:  81 | 위치: (601, 1193) | 크기:  56× 22 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 28 | 단어: 3
#
# 144. 'Mila'
#      신뢰도:  20 | 위치: (687, 1188) | 크기:  58× 33 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 28 | 단어: 4
#
# 145. 'Ml'
#      신뢰도:  40 | 위치: (745, 1179) | 크기:  44× 47 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 28 | 단어: 5
#
# 146. 'dole]'
#      신뢰도:  30 | 위치: (782, 1188) | 크기:  73× 32 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 28 | 단어: 6
#
# 147. 'ia'
#      신뢰도:  36 | 위치: (1165, 1188) | 크기: 160× 27 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 28 | 단어: 7
#
# 148. 'HCH'
#      신뢰도:  32 | 위치: ( 84, 1225) | 크기:  49× 24 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 29 | 단어: 1
#
# 149. '303'
#      신뢰도:  87 | 위치: (341, 1218) | 크기:  53× 35 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 29 | 단어: 2
#
# 150. '523'
#      신뢰도:  87 | 위치: (428, 1249) | 크기:   3×  1 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 29 | 단어: 3
#
# 151. '226'
#      신뢰도:  42 | 위치: (609, 1227) | 크기:  36× 19 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 29 | 단어: 4
#
# 152. '|'
#      신뢰도:  77 | 위치: (782, 1229) | 크기:  13× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 29 | 단어: 5
#
# 153. '1'
#      신뢰도:  65 | 위치: (802, 1253) | 크기:   7×  2 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 29 | 단어: 6
#
# 154. '|'
#      신뢰도:  59 | 위치: (828, 1225) | 크기:  27× 29 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 29 | 단어: 7
#
# 155. '[11'
#      신뢰도:  80 | 위치: (1165, 1229) | 크기:  88× 29 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 29 | 단어: 8
#
# 156. 'HGB'
#      신뢰도:  91 | 위치: ( 84, 1251) | 크기:  48× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 30 | 단어: 1
#
# 157. '982162'
#      신뢰도:  37 | 위치: (350, 1254) | 크기:  88× 36 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 30 | 단어: 2
#
# 158. '94'
#      신뢰도:  65 | 위치: (612, 1259) | 크기:  29× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 30 | 단어: 3
#
# 159. 'GI'
#      신뢰도:  49 | 위치: (645, 1259) | 크기:  50× 31 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 30 | 단어: 4
#
# 160. '11'
#      신뢰도:  65 | 위치: (782, 1260) | 크기:  27× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 30 | 단어: 5
#
# 161. '그'
#      신뢰도:  63 | 위치: (1165, 1264) | 크기:  88× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 30 | 단어: 6
#
# 162. 'MCV'
#      신뢰도:  51 | 위치: ( 83, 1284) | 크기:  54× 45 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 31 | 단어: 1
#
# 163. '376'
#      신뢰도:  80 | 위치: (604, 1294) | 크기:  39× 28 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 31 | 단어: 2
#
# 164. '0.'
#      신뢰도:   7 | 위치: (678, 1289) | 크기:  17× 29 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 31 | 단어: 3
#
# 165. 'Or)'
#      신뢰도:  32 | 위치: (758, 1299) | 크기:  97× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 31 | 단어: 4
#
# 166. ')'
#      신뢰도:  80 | 위치: (882, 1301) | 크기:   1× 17 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 31 | 단어: 5
#
# 167. '!'
#      신뢰도:  70 | 위치: (907, 1304) | 크기:   2× 12 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 31 | 단어: 6
#
# 168. '117'
#      신뢰도:  57 | 위치: (1165, 1291) | 크기:  89× 28 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 31 | 단어: 7
#
# 169. 'MCH'
#      신뢰도:  88 | 위치: ( 69, 1319) | 크기:  70× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 32 | 단어: 1
#
# 170. '11.8173'
#      신뢰도:  42 | 위치: (343, 1325) | 크기:  88× 33 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 32 | 단어: 2
#
# 171. '18'
#      신뢰도:  31 | 위치: (614, 1324) | 크기:  31× 22 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 32 | 단어: 3
#
# 172. 're'
#      신뢰도:  68 | 위치: (678, 1332) | 크기:  25× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 32 | 단어: 4
#
# 173. '=.'
#      신뢰도:  21 | 위치: (802, 1331) | 크기:  53× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 32 | 단어: 5
#
# 174. 'oon'
#      신뢰도:  21 | 위치: (1178, 1321) | 크기:  75× 39 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 32 | 단어: 6
#
# 175. 'MCHC'
#      신뢰도:  93 | 위치: ( 72, 1355) | 크기:  80× 48 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 33 | 단어: 1
#
# 176. '28.1-35.8'
#      신뢰도:  71 | 위치: (341, 1358) | 크기:  99× 35 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 33 | 단어: 2
#
# 177. 'as'
#      신뢰도:  55 | 위치: (612, 1345) | 크기:  32× 48 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 33 | 단어: 3
#
# 178. 'a'
#      신뢰도:  33 | 위치: (756, 1321) | 크기:  58× 77 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 33 | 단어: 4
#
# 179. 'Eo'
#      신뢰도:   0 | 위치: (828, 1361) | 크기:  24× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 33 | 단어: 5
#
# 180. '1'
#      신뢰도:  38 | 위치: (1165, 1359) | 크기:  88× 35 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 33 | 단어: 6
#
# 181. 'RDW'
#      신뢰도:  92 | 위치: ( 70, 1389) | 크기:  59× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 34 | 단어: 1
#
# 182. '15-27'
#      신뢰도:  93 | 위치: (375, 1390) | 크기:  60× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 34 | 단어: 2
#
# 183. '23.5%'
#      신뢰도:  25 | 위치: (603, 1395) | 크기:  98× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 34 | 단어: 3
#
# 184. 'Mo'
#      신뢰도:  32 | 위치: (758, 1401) | 크기:  40× 12 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 34 | 단어: 4
#
# 185. '11'
#      신뢰도:  21 | 위치: (823, 1396) | 크기:  32× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 34 | 단어: 5
#
# 186. '|'
#      신뢰도:  80 | 위치: (839, 1388) | 크기:  20× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 34 | 단어: 6
#
# 187. '|_|'
#      신뢰도:  59 | 위치: (1061, 1401) | 크기:  26× 18 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 34 | 단어: 7
#
# 188. '|'
#      신뢰도:  85 | 위치: (1165, 1401) | 크기:  14× 20 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 34 | 단어: 8
#
# 189. '|'
#      신뢰도:  80 | 위치: (1181, 1390) | 크기:  20× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 34 | 단어: 9
#
# 190. '|'
#      신뢰도:  65 | 위치: (1191, 1401) | 크기:  62× 20 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 34 | 단어: 10
#
# 191. 'Relics?)'
#      신뢰도:   0 | 위치: ( 73, 1421) | 크기: 101× 42 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 35 | 단어: 1
#
# 192. '0.0%'
#      신뢰도:  57 | 위치: (608, 1430) | 크기:  95× 28 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 35 | 단어: 2
#
# 193. '='
#      신뢰도:  71 | 위치: (1060, 1423) | 크기:  25× 12 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 35 | 단어: 3
#
# 194. 'RETIC'
#      신뢰도:  92 | 위치: ( 69, 1454) | 크기:  80× 42 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 1
#
# 195. '3-50'
#      신뢰도:  86 | 위치: (386, 1462) | 크기:  46× 34 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 2
#
# 196. '09'
#      신뢰도:  67 | 위치: (609, 1460) | 크기:  31× 31 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 3
#
# 197. 'KAL'
#      신뢰도:  88 | 위치: (652, 1465) | 크기:  25× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 4
#
# 198. '1'
#      신뢰도:  94 | 위치: (777, 1481) | 크기:   1×  3 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 5
#
# 199. '|'
#      신뢰도:  85 | 위치: (809, 1470) | 크기:  14× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 6
#
# 200. 'ㅎㅎㅎ'
#      신뢰도:   0 | 위치: (822, 1458) | 크기: 431× 33 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 7
#
# 201. 'ㄴㄴ'
#      신뢰도:   0 | 위치: (1088, 1454) | 크기:  90× 42 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 8
#
# 202. '|'
#      신뢰도:  73 | 위치: (1177, 1454) | 크기:  27× 42 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 9
#
# 203. '|'
#      신뢰도:  64 | 위치: (1208, 1454) | 크기:  17× 42 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 10
#
# 204. 'Ｌ'
#      신뢰도:  72 | 위치: (1224, 1454) | 크기:  27× 42 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 36 | 단어: 11
#
# 205. '4'
#      신뢰도:  22 | 위치: (406, 1497) | 크기:   1×  3 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 37 | 단어: 1
#
# 206. '…'
#      신뢰도:  42 | 위치: (601, 1495) | 크기:   2×  2 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 37 | 단어: 2
#
# 207. '~'
#      신뢰도:  65 | 위치: (668, 1486) | 크기:   9× 18 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 37 | 단어: 3
#
# 208. 'ee'
#      신뢰도:  37 | 위치: (799, 1492) | 크기: 457× 11 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 37 | 단어: 4
#
# 209. 'WEG'
#      신뢰도:  52 | 위치: ( 79, 1503) | 크기:  56× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 1
#
# 210. '…'
#      신뢰도:  43 | 위치: (351, 1499) | 크기:  34× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 2
#
# 211. '15.01'
#      신뢰도:  94 | 위치: (594, 1489) | 크기:  47× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 3
#
# 212. 'Kab'
#      신뢰도:  53 | 위치: (648, 1489) | 크기:  52× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 4
#
# 213. '|'
#      신뢰도:  64 | 위치: (808, 1505) | 크기:   2×  2 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 5
#
# 214. '|'
#      신뢰도:  44 | 위치: (822, 1504) | 크기:   7×  7 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 6
#
# 215. '|'
#      신뢰도:  69 | 위치: (841, 1504) | 크기:  14× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 7
#
# 216. '베'
#      신뢰도:   0 | 위치: (1112, 1506) | 크기:  29× 15 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 8
#
# 217. '페'
#      신뢰도:  46 | 위치: (1165, 1504) | 크기:  12× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 9
#
# 218. '|'
#      신뢰도:  91 | 위치: (1191, 1505) | 크기:  11× 17 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 10
#
# 219. '|'
#      신뢰도:  87 | 위치: (1216, 1505) | 크기:  11× 17 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 11
#
# 220. '|'
#      신뢰도:  56 | 위치: (1242, 1505) | 크기:   7× 17 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 38 | 단어: 12
#
# 221. '26018080808900'
#      신뢰도:   5 | 위치: ( 70, 1523) | 크기: 201× 50 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 39 | 단어: 1
#
# 222. '그'
#      신뢰도:  44 | 위치: (680, 1534) | 크기:  23× 25 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 39 | 단어: 2
#
# 223. '='
#      신뢰도:  82 | 위치: (1112, 1527) | 크기:  25× 11 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 39 | 단어: 3
#
# 224. '00000'
#      신뢰도:   4 | 위치: ( 89, 1543) | 크기: 107× 77 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 40 | 단어: 1
#
# 225. '2'
#      신뢰도:  44 | 위치: (603, 1569) | 크기:  43× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 40 | 단어: 2
#
# 226. '346000('
#      신뢰도:  36 | 위치: ( 84, 1596) | 크기:  65× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 41 | 단어: 1
#
# 227. '48%'
#      신뢰도:  59 | 위치: (614, 1602) | 크기:  89× 27 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 41 | 단어: 2
#
# 228. 'EOS(%)'
#      신뢰도:  56 | 위치: ( 68, 1628) | 크기:  92× 46 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 42 | 단어: 1
#
# 229. '05%'
#      신뢰도:  31 | 위치: (611, 1638) | 크기:  92× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 42 | 단어: 2
#
# 230. 'BASO'
#      신뢰도:  91 | 위치: ( 84, 1670) | 크기:  64× 31 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 43 | 단어: 1
#
# 231. '(a)'
#      신뢰도:  38 | 위치: (159, 1674) | 크기:  24× 22 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 43 | 단어: 2
#
# 232. '6'
#      신뢰도:  32 | 위치: (611, 1666) | 크기:  93× 32 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 43 | 단어: 3
#
# 233. '1601'
#      신뢰도:  71 | 위치: ( 86, 1700) | 크기:  60× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 44 | 단어: 1
#
# 234. '115-1029'
#      신뢰도:  53 | 위치: (332, 1704) | 크기: 100× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 44 | 단어: 2
#
# 235. '10.7'
#      신뢰도:  81 | 위치: (591, 1706) | 크기:  34× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 44 | 단어: 3
#
# 236. 'Ku'
#      신뢰도:  47 | 위치: (620, 1702) | 크기:  81× 37 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 44 | 단어: 4
#
# 237. 'A]'
#      신뢰도:   0 | 위치: (699, 1691) | 크기: 114× 52 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 44 | 단어: 5
#
# 238. '|'
#      신뢰도:  34 | 위치: (824, 1710) | 크기:  23× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 44 | 단어: 6
#
# 239. 'eT'
#      신뢰도:  19 | 위치: (1163, 1691) | 크기:  27× 52 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 44 | 단어: 7
#
# 240. '|'
#      신뢰도:  48 | 위치: (1202, 1691) | 크기:  18× 52 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 44 | 단어: 8
#
# 241. '|'
#      신뢰도:  65 | 위치: (1223, 1715) | 크기:  26× 16 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 44 | 단어: 9
#
# 242. 'LYMPH)'
#      신뢰도:  71 | 위치: ( 83, 1740) | 크기:  83× 26 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 45 | 단어: 1
#
# 243. '0.92'
#      신뢰도:   0 | 위치: (339, 1736) | 크기:  42× 43 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 45 | 단어: 2
#
# 244. '-6.88'
#      신뢰도:   0 | 위치: (384, 1736) | 크기:  53× 43 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 45 | 단어: 3
#
# 245. '3.43'
#      신뢰도:  90 | 위치: (603, 1740) | 크기:  52× 34 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 45 | 단어: 4
#
# 246. 'Kh'
#      신뢰도:  74 | 위치: (675, 1770) | 크기:   2×  2 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 45 | 단어: 5
#
# 247. 'ie'
#      신뢰도:   0 | 위치: (776, 1740) | 크기:  79× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 45 | 단어: 6
#
# 248. '로'
#      신뢰도:  35 | 위치: (1009, 1747) | 크기:   2× 16 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 45 | 단어: 7
#
# 249. '[그'
#      신뢰도:   0 | 위치: (1165, 1740) | 크기:  85× 33 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 45 | 단어: 8
#
# 250. 'Ee'
#      신뢰도:   0 | 위치: ( 78, 1735) | 크기:  44×165 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 46 | 단어: 1
#
# 251. '005'
#      신뢰도:  48 | 위치: (339, 1771) | 크기:  43× 29 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 46 | 단어: 2
#
# 252. '00'
#      신뢰도:  67 | 위치: (387, 1773) | 크기:  39× 33 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 46 | 단어: 3
#
# 253. '이그'
#      신뢰도:  42 | 위치: (601, 1766) | 크기:  68× 40 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 46 | 단어: 4
#
# 254. '2'
#      신뢰도:  22 | 위치: (650, 1762) | 크기:  22× 57 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 46 | 단어: 5
#
# 255. '|'
#      신뢰도:  16 | 위치: (768, 1775) | 크기:  61× 30 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 46 | 단어: 6
#
# 256. 'a'
#      신뢰도:  12 | 위치: (844, 1762) | 크기:  76× 57 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 46 | 단어: 7
#
# 257. 'TT'
#      신뢰도:  29 | 위치: (1186, 1762) | 크기:  67× 57 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 46 | 단어: 8
#
# 258. 'Eos'
#      신뢰도:  52 | 위치: ( 84, 1809) | 크기:  41× 49 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 47 | 단어: 1
#
# 259. 'Dato'
#      신뢰도:   0 | 위치: (346, 1808) | 크기:  82× 39 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 47 | 단어: 2
#
# 260. 'ae'
#      신뢰도:  40 | 위치: (601, 1810) | 크기:  67× 35 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 47 | 단어: 3
#
# 261. '[1]'
#      신뢰도:   0 | 위치: (777, 1809) | 크기:  28× 36 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 47 | 단어: 4
#
# 262. 'ees'
#      신뢰도:  26 | 위치: (789, 1809) | 크기: 462× 38 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 47 | 단어: 5
#
# 263. 'TTT'
#      신뢰도:  33 | 위치: (1164, 1805) | 크기:  91× 54 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 47 | 단어: 6
#
# 264. 'BASO'
#      신뢰도:  92 | 위치: ( 84, 1838) | 크기:  60× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 48 | 단어: 1
#
# 265. '001-026'
#      신뢰도:  25 | 위치: (346, 1847) | 크기:  88× 29 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 48 | 단어: 2
#
# 266. '10.01'
#      신뢰도:  49 | 위치: (600, 1846) | 크기:  58× 34 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 48 | 단어: 3
#
# 267. 'Ki'
#      신뢰도:  63 | 위치: (665, 1877) | 크기:  12×  3 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 48 | 단어: 4
#
# 268. '1'
#      신뢰도:  45 | 위치: (762, 1849) | 크기:  33× 20 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 48 | 단어: 5
#
# 269. '11'
#      신뢰도:  44 | 위치: (809, 1838) | 크기:  31× 43 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 48 | 단어: 6
#
# 270. 'CELL'
#      신뢰도:  21 | 위치: (1165, 1849) | 크기:  85× 28 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 48 | 단어: 7
#
# 271. '|'
#      신뢰도:  36 | 위치: ( 78, 1901) | 크기:   2×  6 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 1
#
# 272. 'PLT)'
#      신뢰도:  36 | 위치: ( 83, 1875) | 크기:  44× 38 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 2
#
# 273. '151-000'
#      신뢰도:  37 | 위치: (353, 1855) | 크기:  83× 58 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 3
#
# 274. '8'
#      신뢰도:   8 | 위치: (627, 1879) | 크기:  17× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 4
#
# 275. 'KAD'
#      신뢰도:  45 | 위치: (647, 1875) | 크기:  59× 39 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 5
#
# 276. '|'
#      신뢰도:  87 | 위치: (782, 1883) | 크기:  12× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 6
#
# 277. '|'
#      신뢰도:  53 | 위치: (809, 1887) | 크기:  11× 17 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 7
#
# 278. 'ㅣ'
#      신뢰도:  72 | 위치: (841, 1883) | 크기:  14× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 8
#
# 279. '|'
#      신뢰도:  74 | 위치: (1165, 1883) | 크기:  12× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 9
#
# 280. 'ㅣ'
#      신뢰도:  70 | 위치: (1176, 1879) | 크기:  23× 35 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 10
#
# 281. '|'
#      신뢰도:   0 | 위치: (1198, 1883) | 크기:  31× 21 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 11
#
# 282. '14'
#      신뢰도:   0 | 위치: (1231, 1879) | 크기:  27× 35 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 12
#
# 283. 'ㅣ'
#      신뢰도:  84 | 위치: (1349, 1900) | 크기:   9× 10 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 49 | 단어: 13
#
# 284. '024-11.07.2'
#      신뢰도:  31 | 위치: ( 81, 1923) | 크기: 110× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 50 | 단어: 1
#
# 285. '='
#      신뢰도:  63 | 위치: (194, 1936) | 크기:  15× 18 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 50 | 단어: 2
#
# 286. '04-09)'
#      신뢰도:  71 | 위치: (209, 1923) | 크기:  62× 44 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 50 | 단어: 3
#
# 287. 'Page:'
#      신뢰도:  95 | 위치: (1277, 1937) | 크기:  46× 23 | 레벨: 5 | 블록: 1 | 문단: 1 | 라인: 50 | 단어: 4
#
# 💾 OCR 결과 JSON 저장: debug_output/ocr_result_20241107.json
#
# 🔍 원본 Tesseract 데이터 구조:
# DICT 데이터 키: ['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text']
#   level: 340개 항목
#   page_num: 340개 항목
#   block_num: 340개 항목
#   par_num: 340개 항목
#   line_num: 340개 항목
#   word_num: 340개 항목
#   left: 340개 항목
#   top: 340개 항목
#   width: 340개 항목
#   height: 340개 항목
#   conf: 340개 항목
#   text: 340개 항목
#
# TSV 데이터 샘플 (최대 5개):
#   TSV 1: {'level': '1', 'page_num': '1', 'block_num': '0', 'par_num': '0', 'line_num': '0', 'word_num': '0', 'left': '0', 'top': '0', 'width': '1441', 'height': '2024', 'conf': '-1', 'text': ''}
#   TSV 2: {'level': '2', 'page_num': '1', 'block_num': '1', 'par_num': '0', 'line_num': '0', 'word_num': '0', 'left': '65', 'top': '138', 'width': '1295', 'height': '1829', 'conf': '-1', 'text': ''}
#   TSV 3: {'level': '3', 'page_num': '1', 'block_num': '1', 'par_num': '1', 'line_num': '0', 'word_num': '0', 'left': '68', 'top': '138', 'width': '1292', 'height': '1822', 'conf': '-1', 'text': ''}
#   TSV 4: {'level': '4', 'page_num': '1', 'block_num': '1', 'par_num': '1', 'line_num': '1', 'word_num': '0', 'left': '84', 'top': '138', 'width': '560', 'height': '44', 'conf': '-1', 'text': ''}
#   TSV 5: {'level': '5', 'page_num': '1', 'block_num': '1', 'par_num': '1', 'line_num': '1', 'word_num': '1', 'left': '84', 'top': '138', 'width': '122', 'height': '44', 'conf': '4', 'text': 'LYMPHO,'}
