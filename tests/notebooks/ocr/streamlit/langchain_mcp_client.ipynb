# %%
# %pip install -U langchain-mcp-adapters langgraph langchain-openai
# Out:
# Requirement already satisfied: langchain-mcp-adapters in /home/aidan/.local/lib/python3.10/site-packages (0.1.11)
# Requirement already satisfied: langgraph in /home/aidan/.local/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: langchain-openai in /home/aidan/.local/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: langchain-core<2,>=0.3.36 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-mcp-adapters) (1.0.1)
# Requirement already satisfied: mcp>=1.9.2 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-mcp-adapters) (1.19.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-mcp-adapters) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-core<2,>=0.3.36->langchain-mcp-adapters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-core<2,>=0.3.36->langchain-mcp-adapters) (0.4.38)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-core<2,>=0.3.36->langchain-mcp-adapters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-core<2,>=0.3.36->langchain-mcp-adapters) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-core<2,>=0.3.36->langchain-mcp-adapters) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-core<2,>=0.3.36->langchain-mcp-adapters) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/aidan/miniconda3/envs/meow-chat/lib/python3.10/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/aidan/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /home/aidan/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/aidan/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/aidan/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /home/aidan/.local/lib/python3.10/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (0.25.0)
# Requirement already satisfied: anyio in /home/aidan/miniconda3/envs/meow-chat/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (4.10.0)
# Requirement already satisfied: certifi in /home/aidan/miniconda3/envs/meow-chat/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/aidan/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (1.0.9)
# Requirement already satisfied: idna in /home/aidan/miniconda3/envs/meow-chat/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/aidan/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/aidan/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/aidan/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/aidan/.local/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (0.4.2)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /home/aidan/.local/lib/python3.10/site-packages (from langgraph) (3.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.0 in /home/aidan/.local/lib/python3.10/site-packages (from langgraph) (1.0.1)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /home/aidan/.local/lib/python3.10/site-packages (from langgraph) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /home/aidan/.local/lib/python3.10/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /home/aidan/.local/lib/python3.10/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.11.0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-openai) (2.6.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /home/aidan/.local/lib/python3.10/site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/aidan/miniconda3/envs/meow-chat/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/aidan/.local/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.11.0)
# Requirement already satisfied: sniffio in /home/aidan/.local/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/aidan/.local/lib/python3.10/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/aidan/.local/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (1.3.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/aidan/.local/lib/python3.10/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.10.23)
# Requirement already satisfied: httpx-sse>=0.4 in /home/aidan/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/aidan/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/aidan/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/aidan/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/aidan/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /home/aidan/miniconda3/envs/meow-chat/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.49.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /home/aidan/.local/lib/python3.10/site-packages (from mcp>=1.9.2->langchain-mcp-adapters) (0.38.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/aidan/.local/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/aidan/.local/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/aidan/.local/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/aidan/.local/lib/python3.10/site-packages (from jsonschema>=4.20.0->mcp>=1.9.2->langchain-mcp-adapters) (0.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/aidan/.local/lib/python3.10/site-packages (from pydantic-settings>=2.5.2->mcp>=1.9.2->langchain-mcp-adapters) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/aidan/.local/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/aidan/miniconda3/envs/meow-chat/lib/python3.10/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=0.3.36->langchain-mcp-adapters) (2.5.0)
# Requirement already satisfied: click>=7.0 in /home/aidan/miniconda3/envs/meow-chat/lib/python3.10/site-packages (from uvicorn>=0.31.1->mcp>=1.9.2->langchain-mcp-adapters) (8.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import openai
from dotenv import load_dotenv

load_dotenv("/home/aidan/work/meow-chat/.env")

openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
# Create server parameters for stdio connection
from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client

from langchain_mcp_adapters.tools import load_mcp_tools
from langgraph.prebuilt import create_react_agent

from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o-mini")

server_params = StdioServerParameters(
    command="python3",
    args=["./math_server.py"],
)

async with stdio_client(server_params) as (read, write):
    async with ClientSession(read, write) as session:
        # Initialize the connection
        await session.initialize()

        # Get tools
        tools = await load_mcp_tools(session)

        # Create and run the agent
        agent = create_react_agent(model, tools)
        agent_response = await agent.ainvoke({"messages": "(3 + 5) x 12는 얼마지?"})

agent_response
# Out:
#   + Exception Group Traceback (most recent call last):
#   |   File "/home/aidan/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#   |     await eval(code_obj, self.user_global_ns, self.user_ns)
#   |   File "/tmp/ipykernel_229480/4285305349.py", line 16, in <module>
#   |     async with stdio_client(server_params) as (read, write):
#   |   File "/home/aidan/miniconda3/envs/meow-chat/lib/python3.10/contextlib.py", line 217, in __aexit__
#   |     await self.gen.athrow(typ, value, traceback)
#   |   File "/home/aidan/.local/lib/python3.10/site-packages/mcp/client/stdio/__init__.py", line 182, in stdio_client
#   |     async with (
#   |   File "/home/aidan/miniconda3/envs/meow-chat/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 781, in __aexit__
#   |     raise BaseExceptionGroup(
#   | exceptiongroup.ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | Exception Group Traceback (most recent call last):
#     |   File "/home/aidan/.local/lib/python3.10/site-packages/mcp/client/stdio/__init__.py", line 189, in stdio_client
#     |     yield read_stream, write_stream
#     |   File "/tmp/ipykernel_229480/4285305349.py", line 17, in <module>
#     |     async with ClientSession(read, write) as session:
#     |   File "/home/aidan/.local/lib/python3.10/site-packages/mcp/shared/session.py", line 218, in __aexit__
#     |     return await self._task_group.__aexit__(exc_type, exc_val, exc_tb)
#     |   File "/home/aidan/miniconda3/envs/meow-chat/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 781, in __aexit__
#     |     raise BaseExceptionGroup(
#     | exceptiongroup.ExceptionGroup: unhandled errors in a TaskGroup (1 sub-exception)
#     +-+---------------- 1 ----------------
#       | Traceback (most recent call last):
#       |   File "/tmp/ipykernel_229480/4285305349.py", line 19, in <module>
#       |     await session.initialize()
#       |   File "/home/aidan/.local/lib/python3.10/site-packages/mcp/client/session.py", line 152, in initialize
#       |     result = await self.send_request(
#       |   File "/home/aidan/.local/lib/python3.10/site-packages/mcp/shared/session.py", line 286, in send_request
#       |     raise McpError(response_or_error.error)
#       | mcp.shared.exceptions.McpError: Connection closed
#       +------------------------------------

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
from langgraph.prebuilt import create_react_agent

from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o")

client = MultiServerMCPClient(
    {
        "math": {
            "command": "python3",
            # Make sure to update to the full absolute path to your math_server.py file
            "args": ["./math_server.py"],
            "transport": "stdio",
        },
        "weather": {
            # make sure you start your weather server on port 8000
            "url": "http://localhost:8000/sse",
            "transport": "sse",
        }
    }
) 
agent = create_react_agent(model, await client.get_tools())
math_response = await agent.ainvoke({"messages": "(3 + 5) x 12는 얼마지?"})
weather_response = await agent.ainvoke({"messages": "뉴욕의 날씨는 어때?"})

# %%
math_response

# %%
weather_response
