# %%
# %pip install openai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI

client = OpenAI(
  api_key="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"
)

response = client.responses.create(
  model="gpt-5-nano",
  input="write a haiku about ai",
  store=True,
)

print(response.output_text);
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 7
#       1 from openai import OpenAI
#       3 client = OpenAI(
#       4   api_key="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"
#       5 )
# ----> 7 response = client.responses.create(
#       8   model="gpt-5-nano",
#       9   input="write a haiku about ai",
#      10   store=True,
#      11 )
#      13 print(response.output_text);
#
# ...
